# %%
#데이터 핸들링 라이브러리
import pandas as pd
import numpy as np
#데이터 시각화 라이브러리
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
plt.rcParams.update({'font.family':'AppleGothic'})
mpl.rc('axes', unicode_minus=False)
# %config InlineBackend.figure_format = 'retina'

# %%
# !jupyter nbconvert --to script 전국교통사고_XGB_light_Logistic.ipynb
# Out:
# [NbConvertApp] Converting notebook 전국교통사고_XGB_light_Logistic.ipynb to script
# [NbConvertApp] Writing 11932 bytes to 전국교통사고_XGB_light_Logistic.py

# %% [markdown]
# ## 데이터 전처리 계획
# 1. 데이터 불러오기, 결측치 처리하기
# 2. 상대적으로 중요성이 떨어져보이는 피처 삭제, 필요하면 피처명을 직관적으로 다시 네이밍하기
# 3. 비숫자-문자열 독립변수 인코딩하기
# 4. 데이터 정규화
# 5. 훈련-테스트셋 분리
#
# ## 모델 학습 계획
# 1. 모델 생성
# 2. Cross_validation을 통한 모델학습
# 3. Accuracy, Precision,Recall, ROC 4개의 지표로 분류모델의 정확도 평가하기

# %%
#1. 데이터 불러오기 from TAAS: http://taas.koroad.or.kr/web/shp/sbm/initGisAnals.do?menuId=WEB_KMP_GIS_TAS
## 해당 경로에 있는 .csv 파일명 리스트 가져오기

import os
import time
t_0= time.time()

path = '../교통사고_2021/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.xls')] ## 파일명 끝이 .xls인 경우

## csv 파일들을 DataFrame으로 불러와서 concat

death_df_org = pd.DataFrame()
for i in file_list_py:
    data = pd.read_html(path + i)
    data= data[0]
    death_df_org = pd.concat([death_df_org,data])

death_df_org = death_df_org.reset_index(drop = True)
print(f'데이터 불러오기 및 통합에 걸린 시간은 {str(time.time()-t_0)} 입니다')
death_df= death_df_org.copy()
# Out:
# 데이터 불러오기 및 통합에 걸린 시간은 30.195999145507812 입니다

# %%
"""
결측치 확인하기 => 피해운전자의 차종,성별,연령,상해정도를 파악하지 못하는 데이터가 6687건이 존재함
원본데이터 194094에 비하면 삭제해도 학습에 영향력을 크게 미치지 못할 뿐더러, 이러한 데이터들이
특정 편향성을 갖고 존재할 것이라 보기 어렵다(아마도 기록 누락에 의해 이러한 데이터가 존재할 것이기 때문)
그렇기 때문에 데이터를 제거해도 될것이라 판단하였음
"""
death_df.isnull().sum()
death_df.dropna(inplace=True)
death_df.isnull().sum()
# Out:
# 사고번호          0
# 사고일시          0
# 요일            0
# 시군구           0
# 사고내용          0
# 사망자수          0
# 중상자수          0
# 경상자수          0
# 부상신고자수        0
# 사고유형          0
# 법규위반          0
# 노면상태          0
# 기상상태          0
# 도로형태          0
# 가해운전자 차종      0
# 가해운전자 성별      0
# 가해운전자 연령      0
# 가해운전자 상해정도    0
# 피해운전자 차종      0
# 피해운전자 성별      0
# 피해운전자 연령      0
# 피해운전자 상해정도    0
# dtype: int64

# %%
#데이터 정보 찾기
print(death_df.info())
death_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 187407 entries, 2 to 194093
# Data columns (total 22 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   사고번호        187407 non-null  int64
#  1   사고일시        187407 non-null  object
#  2   요일          187407 non-null  object
#  3   시군구         187407 non-null  object
#  4   사고내용        187407 non-null  object
#  5   사망자수        187407 non-null  int64
#  6   중상자수        187407 non-null  int64
#  7   경상자수        187407 non-null  int64
#  8   부상신고자수      187407 non-null  int64
#  9   사고유형        187407 non-null  object
#  10  법규위반        187407 non-null  object
#  11  노면상태        187407 non-null  object
#  12  기상상태        187407 non-null  object
#  13  도로형태        187407 non-null  object
#  14  가해운전자 차종    187407 non-null  object
#  15  가해운전자 성별    187407 non-null  object
#  16  가해운전자 연령    187407 non-null  object
#  17  가해운전자 상해정도  187407 non-null  object
#  18  피해운전자 차종    187407 non-null  object
#  19  피해운전자 성별    187407 non-null  object
#  20  피해운전자 연령    187407 non-null  object
#  21  피해운전자 상해정도  187407 non-null  object
# dtypes: int64(5), object(17)
# memory usage: 32.9+ MB
# None
#                사고번호             사고일시   요일          시군구  사고내용  사망자수  중상자수  \
# 2  2021010100100040  2021년 1월 1일 08시  금요일  강원도 강릉시 강문동  중상사고     0     1
# 3  2021010100100065  2021년 1월 1일 11시  금요일  강원도 강릉시 옥계면  경상사고     0     0
# 4  2021010100100089  2021년 1월 1일 13시  금요일  강원도 동해시 천곡동  경상사고     0     0
# 5  2021010100100123  2021년 1월 1일 15시  금요일  강원도 강릉시 포남동  사망사고     1     0
# 6  2021010100100146  2021년 1월 1일 17시  금요일  강원도 강릉시 옥천동  경상사고     0     0
#
#    경상자수  부상신고자수        사고유형  ... 기상상태         도로형태 가해운전자 차종 가해운전자 성별 가해운전자 연령  \
# 2     0       0  차대사람 - 횡단중  ...   맑음     단일로 - 기타       화물        남      53세
# 3     4       0  차대차 - 측면충돌  ...   맑음   교차로 - 교차로안       승용        남      43세
# 4     2       0  차대차 - 측면충돌  ...   맑음     단일로 - 기타       승용        남      62세
# 5     0       0  차대차 - 측면충돌  ...   맑음   교차로 - 교차로안      원동기        남      16세
# 6     2       0    차대차 - 추돌  ...   맑음  교차로 - 교차로부근       승용        여      33세
#
#   가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도
# 2       상해없음      보행자        여      20세         중상
# 3       상해없음       화물        남      49세         경상
# 4       상해없음       승용        남      24세         경상
# 5       상해없음       승용        여      50세       상해없음
# 6       상해없음       승용        남      27세         경상
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 종속변수의 카테고리 비율 확인하기
# - 전체 교통사고중 사망사고의 비율은 약 1.15%로, 낮은 비율을 차지하고 있다

# %%
print(death_df['사고내용'].value_counts())
ratio=2149/(138186+47072+2149)
print(f'전체 사고중 사망사고의 비율은 {str(ratio)} 입니다')
# Out:
# 경상사고    138186
# 중상사고     47072
# 사망사고      2149
# Name: 사고내용, dtype: int64
# 전체 사고중 사망사고의 비율은 0.0114670209757373 입니다

# %% [markdown]
# ## 컬럼 핸들링하기
# - 불필요해보이는 컬럼 제거하기
#     1. 사고번호는 각 사고에 대해 일대일 대응되는 key값으로 나중에 데이터를 결합시키는데 사용될 수 있어 보이나, 일단
#     지금 당장 사용되지 않으므로 삭제한다
#     2. 사망자수,중상자수,경상자수,부상신고자는 '피해운전자 상해정도'에 필요한 정보가 담겨있으므로 삭제한다
#     3. 위치정보는 사용하지 않으므로 시군구도 삭제한다
# - 종속변수 '사고내용'에서 사망자를 1, 중상,경상을 0으로 하는 새로운 종속변수열을 만들기
# - 발생년월시에서 시간만 떼어내고, 정수형으로 데이터 변환하고, 22~06시를 야간, 그외 시간을 주간으로 분류하는 데이터 프레임 열 만들기
# - 피해운전자, 가해운전자 연령에서 '세' 단위 떼어내고 정수형으로 데이터 변환하기

# %%
# 경상,중상사고는 0, 사망사고는 1로 라벨링한다
index1= death_df['사고내용']=='사망사고'
death_df['사망사고여부']=index1
death_df
# Out:
#                     사고번호               사고일시   요일               시군구  사고내용  \
# 2       2021010100100040    2021년 1월 1일 08시  금요일       강원도 강릉시 강문동  중상사고
# 3       2021010100100065    2021년 1월 1일 11시  금요일       강원도 강릉시 옥계면  경상사고
# 4       2021010100100089    2021년 1월 1일 13시  금요일       강원도 동해시 천곡동  경상사고
# 5       2021010100100123    2021년 1월 1일 15시  금요일       강원도 강릉시 포남동  사망사고
# 6       2021010100100146    2021년 1월 1일 17시  금요일       강원도 강릉시 옥천동  경상사고
# ...                  ...                ...  ...               ...   ...
# 194089  2021123100100335  2021년 12월 31일 16시  금요일  충청남도 천안시 동남구 광덕면  경상사고
# 194090  2021123100100383  2021년 12월 31일 17시  금요일      충청남도 부여군 장암면  중상사고
# 194091  2021123100100384  2021년 12월 31일 17시  금요일  충청남도 천안시 동남구 청당동  경상사고
# 194092  2021123100100578  2021년 12월 31일 21시  금요일      충청남도 보령시 명천동  경상사고
# 194093  2021123100100631  2021년 12월 31일 23시  금요일      충청남도 예산군 삽교읍  중상사고
#
#         사망자수  중상자수  경상자수  부상신고자수        사고유형  ...         도로형태 가해운전자 차종  \
# 2          0     1     0       0  차대사람 - 횡단중  ...     단일로 - 기타       화물
# 3          0     0     4       0  차대차 - 측면충돌  ...   교차로 - 교차로안       승용
# 4          0     0     2       0  차대차 - 측면충돌  ...     단일로 - 기타       승용
# 5          1     0     0       0  차대차 - 측면충돌  ...   교차로 - 교차로안      원동기
# 6          0     0     2       0    차대차 - 추돌  ...  교차로 - 교차로부근       승용
# ...      ...   ...   ...     ...         ...  ...          ...      ...
# 194089     0     0     3       0  차대차 - 측면충돌  ...   교차로 - 교차로안       승용
# 194090     0     1     0       0    차대차 - 추돌  ...     단일로 - 기타       승용
# 194091     0     0     3       0  차대차 - 측면충돌  ...     단일로 - 기타       승용
# 194092     0     0     1       0    차대차 - 추돌  ...      기타 - 기타       승용
# 194093     0     1     0       0   차대사람 - 기타  ...   교차로 - 교차로안       승용
#
#        가해운전자 성별 가해운전자 연령 가해운전자 상해정도 피해운전자 차종 피해운전자 성별 피해운전자 연령 피해운전자 상해정도  \
# 2             남      53세       상해없음      보행자        여      20세         중상
# 3             남      43세       상해없음       화물        남      49세         경상
# 4             남      62세       상해없음       승용        남      24세         경상
# 5             남      16세       상해없음       승용        여      50세       상해없음
# 6             여      33세       상해없음       승용        남      27세         경상
# ...         ...      ...        ...      ...      ...      ...        ...
# 194089        여      32세         경상       승용        남      42세         경상
# 194090        남      24세       상해없음      자전거        남      78세         중상
# 194091        남      25세         경상       승용        남      22세         경상
# 194092        남      59세       상해없음       승용        여      28세         경상
# 194093        남      56세       상해없음      보행자        남      40세         중상
#
#        사망사고여부
# 2       False
# 3       False
# 4       False
# 5        True
# 6       False
# ...       ...
# 194089  False
# 194090  False
# 194091  False
# 194092  False
# 194093  False
#
# [187407 rows x 23 columns]

# %%
#불필요해보이는 컬럼 제거
death_df.drop(['사고번호','시군구','사망자수','중상자수',
               '경상자수','부상신고자수','노면상태','가해운전자 상해정도','피해운전자 상해정도','사고내용'],axis=1,inplace=True)

##시간에 따른 시계가 교통사고의 요인중 하나일 수 있으므로 발생년월일시에서 시간만 떼어 새로운 컬럼으로 만듬
time_lst= list(death_df['사고일시'])
hour_lst=[]
for time in time_lst:
    hour_lst.append((str(time)[-3:-1]))
death_df['사고시각']= hour_lst
#사고일시 컬럼은 삭제
death_df.drop(['사고일시'],axis=1,inplace=True)

#피해운전자, 가해운전자 연령 미분류 삭제하기
idx= death_df[death_df['피해운전자 연령']=='미분류'].index
death_df.drop(idx,inplace=True)
idx= death_df[death_df['피해운전자 연령']=='98세 이상'].index
death_df.drop(idx,inplace=True)

idx2= death_df[death_df['가해운전자 연령']=='미분류'].index
death_df.drop(idx2,inplace=True)

#나이 컬럼: 숫자단위만 뽑기
suspect_lst= list(death_df['가해운전자 연령'])
suspect_old= []
for old in suspect_lst:
    suspect_old.append((old)[:-1])

death_df['가해운전자 연령']=suspect_old

victim_lst= list(death_df['피해운전자 연령'])
victim_old= []
for old in victim_lst:
    victim_old.append((old)[:-1])
death_df['피해운전자 연령']=victim_old

# %%
index2= death_df['사고시각']=='22','23','24','1','2','3','4','5','6'
death_df['야간여부']=index2[0]
death_df.drop(['사고시각'],axis=1,inplace=True)

# %%
death_df=death_df.reindex(columns=['야간여부','사고유형','법규위반','기상상태','도로형태',
                                   '가해운전자 차종','가해운전자 성별','가해운전자 연령',
                                   '피해운전자 차종','피해운전자 성별','피해운전자 연령','사망사고여부'])

# %%
#데이터 자료형 변환: 문자열-> 정수형
death_df['가해운전자 연령']=death_df['가해운전자 연령'].astype('int')
death_df['피해운전자 연령']=death_df['피해운전자 연령'].astype('int')

# %%
death_df
# Out:
#          야간여부        사고유형       법규위반 기상상태         도로형태 가해운전자 차종 가해운전자 성별  \
# 2       False  차대사람 - 횡단중  보행자보호의무위반   맑음     단일로 - 기타       화물        남
# 3       False  차대차 - 측면충돌       신호위반   맑음   교차로 - 교차로안       승용        남
# 4       False  차대차 - 측면충돌         기타   맑음     단일로 - 기타       승용        남
# 5       False  차대차 - 측면충돌    안전운전불이행   맑음   교차로 - 교차로안      원동기        남
# 6       False    차대차 - 추돌    안전운전불이행   맑음  교차로 - 교차로부근       승용        여
# ...       ...         ...        ...  ...          ...      ...      ...
# 194089  False  차대차 - 측면충돌       신호위반   맑음   교차로 - 교차로안       승용        여
# 194090  False    차대차 - 추돌    안전운전불이행   맑음     단일로 - 기타       승용        남
# 194091  False  차대차 - 측면충돌    안전운전불이행   맑음     단일로 - 기타       승용        남
# 194092  False    차대차 - 추돌         기타   맑음      기타 - 기타       승용        남
# 194093  False   차대사람 - 기타    안전운전불이행   맑음   교차로 - 교차로안       승용        남
#
#         가해운전자 연령 피해운전자 차종 피해운전자 성별  피해운전자 연령  사망사고여부
# 2             53      보행자        여        20   False
# 3             43       화물        남        49   False
# 4             62       승용        남        24   False
# 5             16       승용        여        50    True
# 6             33       승용        남        27   False
# ...          ...      ...      ...       ...     ...
# 194089        32       승용        남        42   False
# 194090        24      자전거        남        78   False
# 194091        25       승용        남        22   False
# 194092        59       승용        여        28   False
# 194093        56      보행자        남        40   False
#
# [184916 rows x 12 columns]

# %% [markdown]
# ![](https://scikit-learn.org/stable/_images/multi_org_chart.png)

# %% [markdown]
# ## 3.범주형 변수 인코딩하기(한번만 인코딩 해야됨 두번하면 안됨)
# - 랜덤 포레스트나 트리 기반 알고리즘의 경우 LabelEncdoer를 활용한 인코딩을 하여도 되나, 그 외의 경우 One-Hot Encoding을 하여야 한다
# - One-Hot Encoding으로 sklearn에도 모듈이 있지만 pd.get_dummies가 사용편의성이 좋은듯
# - [아 졸려](https://blog.roboflow.com/precision-and-recall/#precision-and-recall-examples)

# %%
#features=['야간여부','사고유형','법규위반','기상상태','도로형태','가해운전자 차종','피해운전자 차종','사망사고여부']
features=['야간여부','사고유형','법규위반','기상상태','도로형태',
         '가해운전자 차종','가해운전자 성별',
         '피해운전자 차종','피해운전자 성별','사망사고여부']
encoded_df_org= pd.get_dummies(data=death_df,columns=features,prefix=features)
encoded_df=encoded_df_org.copy()

# %%
#데이터 분리시키기
y=encoded_df['사망사고여부_True']
X=encoded_df.drop(['사망사고여부_True','사망사고여부_False'],axis=1)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train,y_test= train_test_split(X,y,test_size=0.2)

#X_train,y_train을 다시 학습과 검증 데이터셋으로 분리
X_tr,X_val, y_tr,y_val =train_test_split(X_train,y_train,test_size=0.3,random_state=0)

# %%
#모델1. XGBclassifier

from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score,precision_score,roc_auc_score,recall_score

# n_estimators 는 500, random_state는 예제 수행시마다 동일 예측 결과를 위해 설정한다
xgb_clf= XGBClassifier(n_estimators=300,learning_rate=0.05)

#성능 평가 지표를 auc로, 조기 중단 파라미터를 100으로 설정하고 학습을 수행시킨다
xgb_clf.fit(X_tr,y_tr,early_stopping_rounds=100,eval_metric='auc',eval_set=[(X_tr,y_tr),(X_val,y_val)])

#ROC의 정의: ROC, X축이 FPR( FP/(FP+TN), 음성인 것들의 수에서 양성이라 잘못 예측한 것의 비),
# 축은 TNR( TP/(FN+TP), 양성 중에서 양성이라 올바로 예측한 것의 비)
#ROC_AUC(Area Under Curve)는 보통 0.7이상이면 그럭저럭 괜찮고 0.8이면 좋은 모델이라 볼 수 있다

#모델 평가
roc_val= roc_auc_score(y_test,xgb_clf.predict_proba(X_test)[:,1])
recall_val= recall_score(y_test,xgb_clf.predict(X_test))
accuracy_val= accuracy_score(y_test,xgb_clf.predict(X_test))
precision_val= precision_score(y_test,xgb_clf.predict(X_test))
print('\n--------------------------------------')
print(f'ROC_AUC는 {roc_val} 입니다')
print(f'recall_score는 {recall_val} 입니다')
print(f'precision_score는 {precision_val} 입니다')
print(f'accuracy_score는 {accuracy_val} 입니다')
print('--------------------------------------')
#recall_score가 0.036231884057971016: 대부분을 사망안함 0으로 예측안함으로 다른 지표값들을 높여서 이런 현상이 발생했을 가능성이 높음
# Out:
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.77074	validation_1-auc:0.79237
# [1]	validation_0-auc:0.77097	validation_1-auc:0.79327
# [2]	validation_0-auc:0.77440	validation_1-auc:0.79681
# [3]	validation_0-auc:0.77816	validation_1-auc:0.79834
# [4]	validation_0-auc:0.77790	validation_1-auc:0.79844
# [5]	validation_0-auc:0.78049	validation_1-auc:0.79905
# [6]	validation_0-auc:0.79765	validation_1-auc:0.80569
# [7]	validation_0-auc:0.79938	validation_1-auc:0.80637
# [8]	validation_0-auc:0.81315	validation_1-auc:0.81289
# [9]	validation_0-auc:0.81392	validation_1-auc:0.81305
# [10]	validation_0-auc:0.81819	validation_1-auc:0.81528
# [11]	validation_0-auc:0.81933	validation_1-auc:0.81529
# [12]	validation_0-auc:0.81987	validation_1-auc:0.81496
# [13]	validation_0-auc:0.82064	validation_1-auc:0.81633
# [14]	validation_0-auc:0.82456	validation_1-auc:0.81599
# [15]	validation_0-auc:0.82497	validation_1-auc:0.81620
# [16]	validation_0-auc:0.82583	validation_1-auc:0.81650
# [17]	validation_0-auc:0.82595	validation_1-auc:0.81635
# [18]	validation_0-auc:0.82611	validation_1-auc:0.81695
# [19]	validation_0-auc:0.82662	validation_1-auc:0.81705
# [20]	validation_0-auc:0.82669	validation_1-auc:0.81716
# [21]	validation_0-auc:0.82700	validation_1-auc:0.81722
# [22]	validation_0-auc:0.82753	validation_1-auc:0.81831
# [23]	validation_0-auc:0.82791	validation_1-auc:0.81806
# [24]	validation_0-auc:0.82806	validation_1-auc:0.81819
# [25]	validation_0-auc:0.82848	validation_1-auc:0.81802
# [26]	validation_0-auc:0.82862	validation_1-auc:0.81826
# [27]	validation_0-auc:0.82876	validation_1-auc:0.81847
# [28]	validation_0-auc:0.82883	validation_1-auc:0.81828
# [29]	validation_0-auc:0.82908	validation_1-auc:0.81804
# [30]	validation_0-auc:0.82900	validation_1-auc:0.81764
# [31]	validation_0-auc:0.82928	validation_1-auc:0.81801
# [32]	validation_0-auc:0.82932	validation_1-auc:0.81764
# [33]	validation_0-auc:0.82948	validation_1-auc:0.81780
# [34]	validation_0-auc:0.82964	validation_1-auc:0.81799
# [35]	validation_0-auc:0.83269	validation_1-auc:0.82082
# [36]	validation_0-auc:0.83270	validation_1-auc:0.82083
# [37]	validation_0-auc:0.83300	validation_1-auc:0.82074
# [38]	validation_0-auc:0.83303	validation_1-auc:0.82074
# [39]	validation_0-auc:0.83357	validation_1-auc:0.82108
# [40]	validation_0-auc:0.83400	validation_1-auc:0.82106
# [41]	validation_0-auc:0.83420	validation_1-auc:0.82107
# [42]	validation_0-auc:0.83470	validation_1-auc:0.82129
# [43]	validation_0-auc:0.83595	validation_1-auc:0.82218
# [44]	validation_0-auc:0.83703	validation_1-auc:0.82251
# [45]	validation_0-auc:0.83865	validation_1-auc:0.82448
# [46]	validation_0-auc:0.84156	validation_1-auc:0.82515
# [47]	validation_0-auc:0.84186	validation_1-auc:0.82508
# [48]	validation_0-auc:0.84288	validation_1-auc:0.82583
# [49]	validation_0-auc:0.84322	validation_1-auc:0.82615
# [50]	validation_0-auc:0.84468	validation_1-auc:0.82709
# [51]	validation_0-auc:0.84509	validation_1-auc:0.82795
# [52]	validation_0-auc:0.84531	validation_1-auc:0.82810
# [53]	validation_0-auc:0.84562	validation_1-auc:0.82840
# [54]	validation_0-auc:0.84581	validation_1-auc:0.82817
# [55]	validation_0-auc:0.84661	validation_1-auc:0.82870
# [56]	validation_0-auc:0.84779	validation_1-auc:0.82933
# [57]	validation_0-auc:0.84916	validation_1-auc:0.83042
# [58]	validation_0-auc:0.85052	validation_1-auc:0.83142
# [59]	validation_0-auc:0.85088	validation_1-auc:0.83179
# [60]	validation_0-auc:0.85419	validation_1-auc:0.83729
# [61]	validation_0-auc:0.85503	validation_1-auc:0.83767
# [62]	validation_0-auc:0.85634	validation_1-auc:0.83795
# [63]	validation_0-auc:0.85676	validation_1-auc:0.83788
# [64]	validation_0-auc:0.85762	validation_1-auc:0.83828
# [65]	validation_0-auc:0.85867	validation_1-auc:0.83843
# [66]	validation_0-auc:0.85899	validation_1-auc:0.83829
# [67]	validation_0-auc:0.85969	validation_1-auc:0.83857
# [68]	validation_0-auc:0.86103	validation_1-auc:0.83978
# [69]	validation_0-auc:0.86155	validation_1-auc:0.83988
# [70]	validation_0-auc:0.86220	validation_1-auc:0.84016
# [71]	validation_0-auc:0.86451	validation_1-auc:0.84157
# [72]	validation_0-auc:0.86516	validation_1-auc:0.84167
# [73]	validation_0-auc:0.86579	validation_1-auc:0.84200
# [74]	validation_0-auc:0.86657	validation_1-auc:0.84236
# [75]	validation_0-auc:0.86717	validation_1-auc:0.84236
# [76]	validation_0-auc:0.86788	validation_1-auc:0.84232
# [77]	validation_0-auc:0.86882	validation_1-auc:0.84290
# [78]	validation_0-auc:0.86937	validation_1-auc:0.84346
# [79]	validation_0-auc:0.86982	validation_1-auc:0.84376
# [80]	validation_0-auc:0.87072	validation_1-auc:0.84447
# [81]	validation_0-auc:0.87182	validation_1-auc:0.84482
# [82]	validation_0-auc:0.87271	validation_1-auc:0.84510
# [83]	validation_0-auc:0.87333	validation_1-auc:0.84521
# [84]	validation_0-auc:0.87423	validation_1-auc:0.84562
# [85]	validation_0-auc:0.87490	validation_1-auc:0.84579
# [86]	validation_0-auc:0.87543	validation_1-auc:0.84615
# [87]	validation_0-auc:0.87608	validation_1-auc:0.84611
# [88]	validation_0-auc:0.87662	validation_1-auc:0.84616
# [89]	validation_0-auc:0.87713	validation_1-auc:0.84629
# [90]	validation_0-auc:0.87749	validation_1-auc:0.84669
# [91]	validation_0-auc:0.87804	validation_1-auc:0.84719
# [92]	validation_0-auc:0.87851	validation_1-auc:0.84755
# [93]	validation_0-auc:0.87919	validation_1-auc:0.84812
# [94]	validation_0-auc:0.87971	validation_1-auc:0.84829
# [95]	validation_0-auc:0.88083	validation_1-auc:0.84932
# [96]	validation_0-auc:0.88158	validation_1-auc:0.84930
# [97]	validation_0-auc:0.88201	validation_1-auc:0.84960
# [98]	validation_0-auc:0.88257	validation_1-auc:0.85000
# [99]	validation_0-auc:0.88343	validation_1-auc:0.84984
# [100]	validation_0-auc:0.88404	validation_1-auc:0.85037
# [101]	validation_0-auc:0.88444	validation_1-auc:0.85045
# [102]	validation_0-auc:0.88487	validation_1-auc:0.85053
# [103]	validation_0-auc:0.88531	validation_1-auc:0.85043
# [104]	validation_0-auc:0.88596	validation_1-auc:0.85063
# [105]	validation_0-auc:0.88661	validation_1-auc:0.85154
# [106]	validation_0-auc:0.88711	validation_1-auc:0.85207
# [107]	validation_0-auc:0.88780	validation_1-auc:0.85209
# [108]	validation_0-auc:0.88828	validation_1-auc:0.85254
# [109]	validation_0-auc:0.88889	validation_1-auc:0.85247
# [110]	validation_0-auc:0.88928	validation_1-auc:0.85294
# [111]	validation_0-auc:0.88971	validation_1-auc:0.85343
# [112]	validation_0-auc:0.89002	validation_1-auc:0.85377
# [113]	validation_0-auc:0.89060	validation_1-auc:0.85367
# [114]	validation_0-auc:0.89101	validation_1-auc:0.85414
# [115]	validation_0-auc:0.89141	validation_1-auc:0.85473
# [116]	validation_0-auc:0.89171	validation_1-auc:0.85484
# [117]	validation_0-auc:0.89206	validation_1-auc:0.85516
# [118]	validation_0-auc:0.89239	validation_1-auc:0.85492
# [119]	validation_0-auc:0.89280	validation_1-auc:0.85543
# [120]	validation_0-auc:0.89311	validation_1-auc:0.85577
# [121]	validation_0-auc:0.89339	validation_1-auc:0.85569
# [122]	validation_0-auc:0.89370	validation_1-auc:0.85609
# [123]	validation_0-auc:0.89408	validation_1-auc:0.85637
# [124]	validation_0-auc:0.89435	validation_1-auc:0.85664
# [125]	validation_0-auc:0.89484	validation_1-auc:0.85650
# [126]	validation_0-auc:0.89512	validation_1-auc:0.85662
# [127]	validation_0-auc:0.89572	validation_1-auc:0.85684
# [128]	validation_0-auc:0.89599	validation_1-auc:0.85705
# [129]	validation_0-auc:0.89652	validation_1-auc:0.85715
# [130]	validation_0-auc:0.89681	validation_1-auc:0.85738
# [131]	validation_0-auc:0.89730	validation_1-auc:0.85744
# [132]	validation_0-auc:0.89763	validation_1-auc:0.85766
# [133]	validation_0-auc:0.89800	validation_1-auc:0.85815
# [134]	validation_0-auc:0.89830	validation_1-auc:0.85823
# [135]	validation_0-auc:0.89880	validation_1-auc:0.85821
# [136]	validation_0-auc:0.89934	validation_1-auc:0.85825
# [137]	validation_0-auc:0.89967	validation_1-auc:0.85823
# [138]	validation_0-auc:0.90024	validation_1-auc:0.85818
# [139]	validation_0-auc:0.90054	validation_1-auc:0.85814
# [140]	validation_0-auc:0.90062	validation_1-auc:0.85831
# [141]	validation_0-auc:0.90109	validation_1-auc:0.85809
# [142]	validation_0-auc:0.90134	validation_1-auc:0.85815
# [143]	validation_0-auc:0.90143	validation_1-auc:0.85822
# [144]	validation_0-auc:0.90170	validation_1-auc:0.85812
# [145]	validation_0-auc:0.90221	validation_1-auc:0.85810
# [146]	validation_0-auc:0.90236	validation_1-auc:0.85825
# [147]	validation_0-auc:0.90263	validation_1-auc:0.85837
# [148]	validation_0-auc:0.90286	validation_1-auc:0.85840
# [149]	validation_0-auc:0.90308	validation_1-auc:0.85860
# [150]	validation_0-auc:0.90343	validation_1-auc:0.85884
# [151]	validation_0-auc:0.90359	validation_1-auc:0.85882
# [152]	validation_0-auc:0.90378	validation_1-auc:0.85876
# [153]	validation_0-auc:0.90399	validation_1-auc:0.85884
# [154]	validation_0-auc:0.90427	validation_1-auc:0.85900
# [155]	validation_0-auc:0.90427	validation_1-auc:0.85908
# [156]	validation_0-auc:0.90440	validation_1-auc:0.85902
# [157]	validation_0-auc:0.90461	validation_1-auc:0.85889
# [158]	validation_0-auc:0.90476	validation_1-auc:0.85900
# [159]	validation_0-auc:0.90500	validation_1-auc:0.85901
# [160]	validation_0-auc:0.90509	validation_1-auc:0.85899
# [161]	validation_0-auc:0.90532	validation_1-auc:0.85926
# [162]	validation_0-auc:0.90548	validation_1-auc:0.85938
# [163]	validation_0-auc:0.90574	validation_1-auc:0.85950
# [164]	validation_0-auc:0.90605	validation_1-auc:0.85963
# [165]	validation_0-auc:0.90617	validation_1-auc:0.85958
# [166]	validation_0-auc:0.90633	validation_1-auc:0.85968
# [167]	validation_0-auc:0.90653	validation_1-auc:0.85991
# [168]	validation_0-auc:0.90664	validation_1-auc:0.85992
# [169]	validation_0-auc:0.90687	validation_1-auc:0.85988
# [170]	validation_0-auc:0.90697	validation_1-auc:0.85991
# [171]	validation_0-auc:0.90707	validation_1-auc:0.85995
# [172]	validation_0-auc:0.90720	validation_1-auc:0.86003
# [173]	validation_0-auc:0.90740	validation_1-auc:0.86022
# [174]	validation_0-auc:0.90754	validation_1-auc:0.86013
# [175]	validation_0-auc:0.90779	validation_1-auc:0.86015
# [176]	validation_0-auc:0.90789	validation_1-auc:0.86013
# [177]	validation_0-auc:0.90799	validation_1-auc:0.86012
# [178]	validation_0-auc:0.90812	validation_1-auc:0.86007
# [179]	validation_0-auc:0.90823	validation_1-auc:0.86011
# [180]	validation_0-auc:0.90839	validation_1-auc:0.86027
# [181]	validation_0-auc:0.90858	validation_1-auc:0.86036
# [182]	validation_0-auc:0.90865	validation_1-auc:0.86030
# [183]	validation_0-auc:0.90879	validation_1-auc:0.86037
# [184]	validation_0-auc:0.90890	validation_1-auc:0.86025
# [185]	validation_0-auc:0.90907	validation_1-auc:0.86037
# [186]	validation_0-auc:0.90915	validation_1-auc:0.86027
# [187]	validation_0-auc:0.90924	validation_1-auc:0.86012
# [188]	validation_0-auc:0.90934	validation_1-auc:0.86012
# [189]	validation_0-auc:0.90943	validation_1-auc:0.86002
# [190]	validation_0-auc:0.90952	validation_1-auc:0.86004
# [191]	validation_0-auc:0.90967	validation_1-auc:0.86020
# [192]	validation_0-auc:0.90981	validation_1-auc:0.86030
# [193]	validation_0-auc:0.91005	validation_1-auc:0.86040
# [194]	validation_0-auc:0.91013	validation_1-auc:0.86040
# [195]	validation_0-auc:0.91024	validation_1-auc:0.86042
# [196]	validation_0-auc:0.91033	validation_1-auc:0.86044
# [197]	validation_0-auc:0.91044	validation_1-auc:0.86051
# [198]	validation_0-auc:0.91055	validation_1-auc:0.86039
# [199]	validation_0-auc:0.91064	validation_1-auc:0.86038
# [200]	validation_0-auc:0.91073	validation_1-auc:0.86039
# [201]	validation_0-auc:0.91102	validation_1-auc:0.86050
# [202]	validation_0-auc:0.91108	validation_1-auc:0.86053
# [203]	validation_0-auc:0.91113	validation_1-auc:0.86068
# [204]	validation_0-auc:0.91134	validation_1-auc:0.86039
# [205]	validation_0-auc:0.91144	validation_1-auc:0.86042
# [206]	validation_0-auc:0.91162	validation_1-auc:0.86059
# [207]	validation_0-auc:0.91180	validation_1-auc:0.86053
# [208]	validation_0-auc:0.91193	validation_1-auc:0.86066
# [209]	validation_0-auc:0.91201	validation_1-auc:0.86076
# [210]	validation_0-auc:0.91214	validation_1-auc:0.86081
# [211]	validation_0-auc:0.91236	validation_1-auc:0.86073
# [212]	validation_0-auc:0.91247	validation_1-auc:0.86071
# [213]	validation_0-auc:0.91261	validation_1-auc:0.86072
# [214]	validation_0-auc:0.91267	validation_1-auc:0.86065
# [215]	validation_0-auc:0.91273	validation_1-auc:0.86064
# [216]	validation_0-auc:0.91289	validation_1-auc:0.86048
# [217]	validation_0-auc:0.91294	validation_1-auc:0.86056
# [218]	validation_0-auc:0.91311	validation_1-auc:0.86060
# [219]	validation_0-auc:0.91326	validation_1-auc:0.86057
# [220]	validation_0-auc:0.91350	validation_1-auc:0.86043
# [221]	validation_0-auc:0.91355	validation_1-auc:0.86042
# [222]	validation_0-auc:0.91362	validation_1-auc:0.86032
# [223]	validation_0-auc:0.91378	validation_1-auc:0.86034
# [224]	validation_0-auc:0.91378	validation_1-auc:0.86038
# [225]	validation_0-auc:0.91382	validation_1-auc:0.86041
# [226]	validation_0-auc:0.91390	validation_1-auc:0.86033
# [227]	validation_0-auc:0.91401	validation_1-auc:0.86027
# [228]	validation_0-auc:0.91404	validation_1-auc:0.86019
# [229]	validation_0-auc:0.91408	validation_1-auc:0.86021
# [230]	validation_0-auc:0.91423	validation_1-auc:0.86021
# [231]	validation_0-auc:0.91428	validation_1-auc:0.86020
# [232]	validation_0-auc:0.91431	validation_1-auc:0.86021
# [233]	validation_0-auc:0.91459	validation_1-auc:0.86019
# [234]	validation_0-auc:0.91469	validation_1-auc:0.86025
# [235]	validation_0-auc:0.91494	validation_1-auc:0.86027
# [236]	validation_0-auc:0.91497	validation_1-auc:0.86025
# [237]	validation_0-auc:0.91503	validation_1-auc:0.86029
# [238]	validation_0-auc:0.91508	validation_1-auc:0.86022
# [239]	validation_0-auc:0.91522	validation_1-auc:0.86024
# [240]	validation_0-auc:0.91527	validation_1-auc:0.86031
# [241]	validation_0-auc:0.91530	validation_1-auc:0.86028
# [242]	validation_0-auc:0.91533	validation_1-auc:0.86028
# [243]	validation_0-auc:0.91545	validation_1-auc:0.86012
# [244]	validation_0-auc:0.91549	validation_1-auc:0.86020
# [245]	validation_0-auc:0.91554	validation_1-auc:0.86020
# [246]	validation_0-auc:0.91580	validation_1-auc:0.86024
# [247]	validation_0-auc:0.91586	validation_1-auc:0.86020
# [248]	validation_0-auc:0.91591	validation_1-auc:0.86024
# [249]	validation_0-auc:0.91601	validation_1-auc:0.86023
# [250]	validation_0-auc:0.91609	validation_1-auc:0.86022
# [251]	validation_0-auc:0.91613	validation_1-auc:0.86017
# [252]	validation_0-auc:0.91616	validation_1-auc:0.86016
# [253]	validation_0-auc:0.91621	validation_1-auc:0.86015
# [254]	validation_0-auc:0.91622	validation_1-auc:0.86015
# [255]	validation_0-auc:0.91629	validation_1-auc:0.86022
# [256]	validation_0-auc:0.91634	validation_1-auc:0.86008
# [257]	validation_0-auc:0.91652	validation_1-auc:0.86020
# [258]	validation_0-auc:0.91655	validation_1-auc:0.86021
# [259]	validation_0-auc:0.91658	validation_1-auc:0.86024
# [260]	validation_0-auc:0.91664	validation_1-auc:0.86020
# [261]	validation_0-auc:0.91673	validation_1-auc:0.86021
# [262]	validation_0-auc:0.91678	validation_1-auc:0.86017
# [263]	validation_0-auc:0.91692	validation_1-auc:0.86023
# [264]	validation_0-auc:0.91707	validation_1-auc:0.86013
# [265]	validation_0-auc:0.91712	validation_1-auc:0.86009
# [266]	validation_0-auc:0.91714	validation_1-auc:0.86007
# [267]	validation_0-auc:0.91744	validation_1-auc:0.86015
# [268]	validation_0-auc:0.91752	validation_1-auc:0.86017
# [269]	validation_0-auc:0.91757	validation_1-auc:0.86023
# [270]	validation_0-auc:0.91760	validation_1-auc:0.86023
# [271]	validation_0-auc:0.91763	validation_1-auc:0.86020
# [272]	validation_0-auc:0.91777	validation_1-auc:0.86017
# [273]	validation_0-auc:0.91780	validation_1-auc:0.86015
# [274]	validation_0-auc:0.91800	validation_1-auc:0.86016
# [275]	validation_0-auc:0.91818	validation_1-auc:0.86021
# [276]	validation_0-auc:0.91821	validation_1-auc:0.86019
# [277]	validation_0-auc:0.91829	validation_1-auc:0.86022
# [278]	validation_0-auc:0.91835	validation_1-auc:0.86023
# [279]	validation_0-auc:0.91837	validation_1-auc:0.86018
# [280]	validation_0-auc:0.91841	validation_1-auc:0.86018
# [281]	validation_0-auc:0.91866	validation_1-auc:0.86025
# [282]	validation_0-auc:0.91871	validation_1-auc:0.86032
# [283]	validation_0-auc:0.91896	validation_1-auc:0.86026
# [284]	validation_0-auc:0.91904	validation_1-auc:0.86024
# [285]	validation_0-auc:0.91914	validation_1-auc:0.86030
# [286]	validation_0-auc:0.91922	validation_1-auc:0.86037
# [287]	validation_0-auc:0.91949	validation_1-auc:0.86033
# [288]	validation_0-auc:0.91956	validation_1-auc:0.86038
# [289]	validation_0-auc:0.91968	validation_1-auc:0.86038
# [290]	validation_0-auc:0.91977	validation_1-auc:0.86037
# [291]	validation_0-auc:0.91983	validation_1-auc:0.86038
# [292]	validation_0-auc:0.91987	validation_1-auc:0.86038
# [293]	validation_0-auc:0.92000	validation_1-auc:0.86030
# [294]	validation_0-auc:0.92007	validation_1-auc:0.86027
# [295]	validation_0-auc:0.92016	validation_1-auc:0.86024
# [296]	validation_0-auc:0.92029	validation_1-auc:0.86021
# [297]	validation_0-auc:0.92048	validation_1-auc:0.86021
# [298]	validation_0-auc:0.92051	validation_1-auc:0.86014
# [299]	validation_0-auc:0.92053	validation_1-auc:0.86015
#
# --------------------------------------
# ROC_AUC는 0.87070532592495 입니다
# recall_score는 0.04460093896713615 입니다
# precision_score는 0.59375 입니다
# accuracy_score는 0.9886437378325762 입니다
# --------------------------------------
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
#모델1-2. XGBclassifier - Binarizer를 적용한다

from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score,precision_score,roc_auc_score,recall_score
from sklearn.preprocessing import Binarizer

# n_estimators 는 300, random_state는 예제 수행시마다 동일 예측 결과를 위해 설정한다
xgb_clf= XGBClassifier(n_estimators=300,learning_rate=0.05)

#성능 평가 지표를 auc로, 조기 중단 파라미터를 100으로 설정하고 학습을 수행시킨다
xgb_clf.fit(X_tr,y_tr,early_stopping_rounds=100,eval_metric='auc',eval_set=[(X_tr,y_tr),(X_val,y_val)])

#ROC의 정의: ROC, X축이 FPR( FP/(FP+TN), 음성인 것들의 수에서 양성이라 잘못 예측한 것의 비),
# 축은 TNR( TP/(FN+TP), 양성 중에서 양성이라 올바로 예측한 것의 비)
#ROC_AUC(Area Under Curve)는 보통 0.7이상이면 그럭저럭 괜찮고 0.8이면 좋은 모델이라 볼 수 있다

#Binarizer 적용하기
custom_threshold= 0.01
pred_proba_1= xgb_clf.predict_proba(X_test)[:,1].reshape(-1,1)
binarizer= Binarizer(threshold=custom_threshold).fit(pred_proba_1)
custom_predict= binarizer.transform(pred_proba_1)

#모델 평가
roc_val= roc_auc_score(y_test,xgb_clf.predict_proba(X_test)[:,1])
recall_val= recall_score(y_test,custom_predict)
accuracy_val= accuracy_score(y_test,custom_predict)
precision_val= precision_score(y_test,custom_predict)

print('\n--------------------------------------')
print(f'ROC_AUC는 {roc_val} 입니다')
print(f'recall_score는 {recall_val} 입니다')
print(f'precision_score는 {precision_val} 입니다')
print(f'accuracy_score는 {accuracy_val} 입니다')
print('--------------------------------------')
#recall_score가 0.036231884057971016: 대부분을 사망안함 0으로 예측안함으로 다른 지표값들을 높여서 이런 현상이 발생했을 가능성이 높음
# Out:
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [0]	validation_0-auc:0.77074	validation_1-auc:0.79237
# [1]	validation_0-auc:0.77097	validation_1-auc:0.79327
# [2]	validation_0-auc:0.77440	validation_1-auc:0.79681
# [3]	validation_0-auc:0.77816	validation_1-auc:0.79834
# [4]	validation_0-auc:0.77790	validation_1-auc:0.79844
# [5]	validation_0-auc:0.78049	validation_1-auc:0.79905
# [6]	validation_0-auc:0.79765	validation_1-auc:0.80569
# [7]	validation_0-auc:0.79938	validation_1-auc:0.80637
# [8]	validation_0-auc:0.81315	validation_1-auc:0.81289
# [9]	validation_0-auc:0.81392	validation_1-auc:0.81305
# [10]	validation_0-auc:0.81819	validation_1-auc:0.81528
# [11]	validation_0-auc:0.81933	validation_1-auc:0.81529
# [12]	validation_0-auc:0.81987	validation_1-auc:0.81496
# [13]	validation_0-auc:0.82064	validation_1-auc:0.81633
# [14]	validation_0-auc:0.82456	validation_1-auc:0.81599
# [15]	validation_0-auc:0.82497	validation_1-auc:0.81620
# [16]	validation_0-auc:0.82583	validation_1-auc:0.81650
# [17]	validation_0-auc:0.82595	validation_1-auc:0.81635
# [18]	validation_0-auc:0.82611	validation_1-auc:0.81695
# [19]	validation_0-auc:0.82662	validation_1-auc:0.81705
# [20]	validation_0-auc:0.82669	validation_1-auc:0.81716
# [21]	validation_0-auc:0.82700	validation_1-auc:0.81722
# [22]	validation_0-auc:0.82753	validation_1-auc:0.81831
# [23]	validation_0-auc:0.82791	validation_1-auc:0.81806
# [24]	validation_0-auc:0.82806	validation_1-auc:0.81819
# [25]	validation_0-auc:0.82848	validation_1-auc:0.81802
# [26]	validation_0-auc:0.82862	validation_1-auc:0.81826
# [27]	validation_0-auc:0.82876	validation_1-auc:0.81847
# [28]	validation_0-auc:0.82883	validation_1-auc:0.81828
# [29]	validation_0-auc:0.82908	validation_1-auc:0.81804
# [30]	validation_0-auc:0.82900	validation_1-auc:0.81764
# [31]	validation_0-auc:0.82928	validation_1-auc:0.81801
# [32]	validation_0-auc:0.82932	validation_1-auc:0.81764
# [33]	validation_0-auc:0.82948	validation_1-auc:0.81780
# [34]	validation_0-auc:0.82964	validation_1-auc:0.81799
# [35]	validation_0-auc:0.83269	validation_1-auc:0.82082
# [36]	validation_0-auc:0.83270	validation_1-auc:0.82083
# [37]	validation_0-auc:0.83300	validation_1-auc:0.82074
# [38]	validation_0-auc:0.83303	validation_1-auc:0.82074
# [39]	validation_0-auc:0.83357	validation_1-auc:0.82108
# [40]	validation_0-auc:0.83400	validation_1-auc:0.82106
# [41]	validation_0-auc:0.83420	validation_1-auc:0.82107
# [42]	validation_0-auc:0.83470	validation_1-auc:0.82129
# [43]	validation_0-auc:0.83595	validation_1-auc:0.82218
# [44]	validation_0-auc:0.83703	validation_1-auc:0.82251
# [45]	validation_0-auc:0.83865	validation_1-auc:0.82448
# [46]	validation_0-auc:0.84156	validation_1-auc:0.82515
# [47]	validation_0-auc:0.84186	validation_1-auc:0.82508
# [48]	validation_0-auc:0.84288	validation_1-auc:0.82583
# [49]	validation_0-auc:0.84322	validation_1-auc:0.82615
# [50]	validation_0-auc:0.84468	validation_1-auc:0.82709
# [51]	validation_0-auc:0.84509	validation_1-auc:0.82795
# [52]	validation_0-auc:0.84531	validation_1-auc:0.82810
# [53]	validation_0-auc:0.84562	validation_1-auc:0.82840
# [54]	validation_0-auc:0.84581	validation_1-auc:0.82817
# [55]	validation_0-auc:0.84661	validation_1-auc:0.82870
# [56]	validation_0-auc:0.84779	validation_1-auc:0.82933
# [57]	validation_0-auc:0.84916	validation_1-auc:0.83042
# [58]	validation_0-auc:0.85052	validation_1-auc:0.83142
# [59]	validation_0-auc:0.85088	validation_1-auc:0.83179
# [60]	validation_0-auc:0.85419	validation_1-auc:0.83729
# [61]	validation_0-auc:0.85503	validation_1-auc:0.83767
# [62]	validation_0-auc:0.85634	validation_1-auc:0.83795
# [63]	validation_0-auc:0.85676	validation_1-auc:0.83788
# [64]	validation_0-auc:0.85762	validation_1-auc:0.83828
# [65]	validation_0-auc:0.85867	validation_1-auc:0.83843
# [66]	validation_0-auc:0.85899	validation_1-auc:0.83829
# [67]	validation_0-auc:0.85969	validation_1-auc:0.83857
# [68]	validation_0-auc:0.86103	validation_1-auc:0.83978
# [69]	validation_0-auc:0.86155	validation_1-auc:0.83988
# [70]	validation_0-auc:0.86220	validation_1-auc:0.84016
# [71]	validation_0-auc:0.86451	validation_1-auc:0.84157
# [72]	validation_0-auc:0.86516	validation_1-auc:0.84167
# [73]	validation_0-auc:0.86579	validation_1-auc:0.84200
# [74]	validation_0-auc:0.86657	validation_1-auc:0.84236
# [75]	validation_0-auc:0.86717	validation_1-auc:0.84236
# [76]	validation_0-auc:0.86788	validation_1-auc:0.84232
# [77]	validation_0-auc:0.86882	validation_1-auc:0.84290
# [78]	validation_0-auc:0.86937	validation_1-auc:0.84346
# [79]	validation_0-auc:0.86982	validation_1-auc:0.84376
# [80]	validation_0-auc:0.87072	validation_1-auc:0.84447
# [81]	validation_0-auc:0.87182	validation_1-auc:0.84482
# [82]	validation_0-auc:0.87271	validation_1-auc:0.84510
# [83]	validation_0-auc:0.87333	validation_1-auc:0.84521
# [84]	validation_0-auc:0.87423	validation_1-auc:0.84562
# [85]	validation_0-auc:0.87490	validation_1-auc:0.84579
# [86]	validation_0-auc:0.87543	validation_1-auc:0.84615
# [87]	validation_0-auc:0.87608	validation_1-auc:0.84611
# [88]	validation_0-auc:0.87662	validation_1-auc:0.84616
# [89]	validation_0-auc:0.87713	validation_1-auc:0.84629
# [90]	validation_0-auc:0.87749	validation_1-auc:0.84669
# [91]	validation_0-auc:0.87804	validation_1-auc:0.84719
# [92]	validation_0-auc:0.87851	validation_1-auc:0.84755
# [93]	validation_0-auc:0.87919	validation_1-auc:0.84812
# [94]	validation_0-auc:0.87971	validation_1-auc:0.84829
# [95]	validation_0-auc:0.88083	validation_1-auc:0.84932
# [96]	validation_0-auc:0.88158	validation_1-auc:0.84930
# [97]	validation_0-auc:0.88201	validation_1-auc:0.84960
# [98]	validation_0-auc:0.88257	validation_1-auc:0.85000
# [99]	validation_0-auc:0.88343	validation_1-auc:0.84984
# [100]	validation_0-auc:0.88404	validation_1-auc:0.85037
# [101]	validation_0-auc:0.88444	validation_1-auc:0.85045
# [102]	validation_0-auc:0.88487	validation_1-auc:0.85053
# [103]	validation_0-auc:0.88531	validation_1-auc:0.85043
# [104]	validation_0-auc:0.88596	validation_1-auc:0.85063
# [105]	validation_0-auc:0.88661	validation_1-auc:0.85154
# [106]	validation_0-auc:0.88711	validation_1-auc:0.85207
# [107]	validation_0-auc:0.88780	validation_1-auc:0.85209
# [108]	validation_0-auc:0.88828	validation_1-auc:0.85254
# [109]	validation_0-auc:0.88889	validation_1-auc:0.85247
# [110]	validation_0-auc:0.88928	validation_1-auc:0.85294
# [111]	validation_0-auc:0.88971	validation_1-auc:0.85343
# [112]	validation_0-auc:0.89002	validation_1-auc:0.85377
# [113]	validation_0-auc:0.89060	validation_1-auc:0.85367
# [114]	validation_0-auc:0.89101	validation_1-auc:0.85414
# [115]	validation_0-auc:0.89141	validation_1-auc:0.85473
# [116]	validation_0-auc:0.89171	validation_1-auc:0.85484
# [117]	validation_0-auc:0.89206	validation_1-auc:0.85516
# [118]	validation_0-auc:0.89239	validation_1-auc:0.85492
# [119]	validation_0-auc:0.89280	validation_1-auc:0.85543
# [120]	validation_0-auc:0.89311	validation_1-auc:0.85577
# [121]	validation_0-auc:0.89339	validation_1-auc:0.85569
# [122]	validation_0-auc:0.89370	validation_1-auc:0.85609
# [123]	validation_0-auc:0.89408	validation_1-auc:0.85637
# [124]	validation_0-auc:0.89435	validation_1-auc:0.85664
# [125]	validation_0-auc:0.89484	validation_1-auc:0.85650
# [126]	validation_0-auc:0.89512	validation_1-auc:0.85662
# [127]	validation_0-auc:0.89572	validation_1-auc:0.85684
# [128]	validation_0-auc:0.89599	validation_1-auc:0.85705
# [129]	validation_0-auc:0.89652	validation_1-auc:0.85715
# [130]	validation_0-auc:0.89681	validation_1-auc:0.85738
# [131]	validation_0-auc:0.89730	validation_1-auc:0.85744
# [132]	validation_0-auc:0.89763	validation_1-auc:0.85766
# [133]	validation_0-auc:0.89800	validation_1-auc:0.85815
# [134]	validation_0-auc:0.89830	validation_1-auc:0.85823
# [135]	validation_0-auc:0.89880	validation_1-auc:0.85821
# [136]	validation_0-auc:0.89934	validation_1-auc:0.85825
# [137]	validation_0-auc:0.89967	validation_1-auc:0.85823
# [138]	validation_0-auc:0.90024	validation_1-auc:0.85818
# [139]	validation_0-auc:0.90054	validation_1-auc:0.85814
# [140]	validation_0-auc:0.90062	validation_1-auc:0.85831
# [141]	validation_0-auc:0.90109	validation_1-auc:0.85809
# [142]	validation_0-auc:0.90134	validation_1-auc:0.85815
# [143]	validation_0-auc:0.90143	validation_1-auc:0.85822
# [144]	validation_0-auc:0.90170	validation_1-auc:0.85812
# [145]	validation_0-auc:0.90221	validation_1-auc:0.85810
# [146]	validation_0-auc:0.90236	validation_1-auc:0.85825
# [147]	validation_0-auc:0.90263	validation_1-auc:0.85837
# [148]	validation_0-auc:0.90286	validation_1-auc:0.85840
# [149]	validation_0-auc:0.90308	validation_1-auc:0.85860
# [150]	validation_0-auc:0.90343	validation_1-auc:0.85884
# [151]	validation_0-auc:0.90359	validation_1-auc:0.85882
# [152]	validation_0-auc:0.90378	validation_1-auc:0.85876
# [153]	validation_0-auc:0.90399	validation_1-auc:0.85884
# [154]	validation_0-auc:0.90427	validation_1-auc:0.85900
# [155]	validation_0-auc:0.90427	validation_1-auc:0.85908
# [156]	validation_0-auc:0.90440	validation_1-auc:0.85902
# [157]	validation_0-auc:0.90461	validation_1-auc:0.85889
# [158]	validation_0-auc:0.90476	validation_1-auc:0.85900
# [159]	validation_0-auc:0.90500	validation_1-auc:0.85901
# [160]	validation_0-auc:0.90509	validation_1-auc:0.85899
# [161]	validation_0-auc:0.90532	validation_1-auc:0.85926
# [162]	validation_0-auc:0.90548	validation_1-auc:0.85938
# [163]	validation_0-auc:0.90574	validation_1-auc:0.85950
# [164]	validation_0-auc:0.90605	validation_1-auc:0.85963
# [165]	validation_0-auc:0.90617	validation_1-auc:0.85958
# [166]	validation_0-auc:0.90633	validation_1-auc:0.85968
# [167]	validation_0-auc:0.90653	validation_1-auc:0.85991
# [168]	validation_0-auc:0.90664	validation_1-auc:0.85992
# [169]	validation_0-auc:0.90687	validation_1-auc:0.85988
# [170]	validation_0-auc:0.90697	validation_1-auc:0.85991
# [171]	validation_0-auc:0.90707	validation_1-auc:0.85995
# [172]	validation_0-auc:0.90720	validation_1-auc:0.86003
# [173]	validation_0-auc:0.90740	validation_1-auc:0.86022
# [174]	validation_0-auc:0.90754	validation_1-auc:0.86013
# [175]	validation_0-auc:0.90779	validation_1-auc:0.86015
# [176]	validation_0-auc:0.90789	validation_1-auc:0.86013
# [177]	validation_0-auc:0.90799	validation_1-auc:0.86012
# [178]	validation_0-auc:0.90812	validation_1-auc:0.86007
# [179]	validation_0-auc:0.90823	validation_1-auc:0.86011
# [180]	validation_0-auc:0.90839	validation_1-auc:0.86027
# [181]	validation_0-auc:0.90858	validation_1-auc:0.86036
# [182]	validation_0-auc:0.90865	validation_1-auc:0.86030
# [183]	validation_0-auc:0.90879	validation_1-auc:0.86037
# [184]	validation_0-auc:0.90890	validation_1-auc:0.86025
# [185]	validation_0-auc:0.90907	validation_1-auc:0.86037
# [186]	validation_0-auc:0.90915	validation_1-auc:0.86027
# [187]	validation_0-auc:0.90924	validation_1-auc:0.86012
# [188]	validation_0-auc:0.90934	validation_1-auc:0.86012
# [189]	validation_0-auc:0.90943	validation_1-auc:0.86002
# [190]	validation_0-auc:0.90952	validation_1-auc:0.86004
# [191]	validation_0-auc:0.90967	validation_1-auc:0.86020
# [192]	validation_0-auc:0.90981	validation_1-auc:0.86030
# [193]	validation_0-auc:0.91005	validation_1-auc:0.86040
# [194]	validation_0-auc:0.91013	validation_1-auc:0.86040
# [195]	validation_0-auc:0.91024	validation_1-auc:0.86042
# [196]	validation_0-auc:0.91033	validation_1-auc:0.86044
# [197]	validation_0-auc:0.91044	validation_1-auc:0.86051
# [198]	validation_0-auc:0.91055	validation_1-auc:0.86039
# [199]	validation_0-auc:0.91064	validation_1-auc:0.86038
# [200]	validation_0-auc:0.91073	validation_1-auc:0.86039
# [201]	validation_0-auc:0.91102	validation_1-auc:0.86050
# [202]	validation_0-auc:0.91108	validation_1-auc:0.86053
# [203]	validation_0-auc:0.91113	validation_1-auc:0.86068
# [204]	validation_0-auc:0.91134	validation_1-auc:0.86039
# [205]	validation_0-auc:0.91144	validation_1-auc:0.86042
# [206]	validation_0-auc:0.91162	validation_1-auc:0.86059
# [207]	validation_0-auc:0.91180	validation_1-auc:0.86053
# [208]	validation_0-auc:0.91193	validation_1-auc:0.86066
# [209]	validation_0-auc:0.91201	validation_1-auc:0.86076
# [210]	validation_0-auc:0.91214	validation_1-auc:0.86081
# [211]	validation_0-auc:0.91236	validation_1-auc:0.86073
# [212]	validation_0-auc:0.91247	validation_1-auc:0.86071
# [213]	validation_0-auc:0.91261	validation_1-auc:0.86072
# [214]	validation_0-auc:0.91267	validation_1-auc:0.86065
# [215]	validation_0-auc:0.91273	validation_1-auc:0.86064
# [216]	validation_0-auc:0.91289	validation_1-auc:0.86048
# [217]	validation_0-auc:0.91294	validation_1-auc:0.86056
# [218]	validation_0-auc:0.91311	validation_1-auc:0.86060
# [219]	validation_0-auc:0.91326	validation_1-auc:0.86057
# [220]	validation_0-auc:0.91350	validation_1-auc:0.86043
# [221]	validation_0-auc:0.91355	validation_1-auc:0.86042
# [222]	validation_0-auc:0.91362	validation_1-auc:0.86032
# [223]	validation_0-auc:0.91378	validation_1-auc:0.86034
# [224]	validation_0-auc:0.91378	validation_1-auc:0.86038
# [225]	validation_0-auc:0.91382	validation_1-auc:0.86041
# [226]	validation_0-auc:0.91390	validation_1-auc:0.86033
# [227]	validation_0-auc:0.91401	validation_1-auc:0.86027
# [228]	validation_0-auc:0.91404	validation_1-auc:0.86019
# [229]	validation_0-auc:0.91408	validation_1-auc:0.86021
# [230]	validation_0-auc:0.91423	validation_1-auc:0.86021
# [231]	validation_0-auc:0.91428	validation_1-auc:0.86020
# [232]	validation_0-auc:0.91431	validation_1-auc:0.86021
# [233]	validation_0-auc:0.91459	validation_1-auc:0.86019
# [234]	validation_0-auc:0.91469	validation_1-auc:0.86025
# [235]	validation_0-auc:0.91494	validation_1-auc:0.86027
# [236]	validation_0-auc:0.91497	validation_1-auc:0.86025
# [237]	validation_0-auc:0.91503	validation_1-auc:0.86029
# [238]	validation_0-auc:0.91508	validation_1-auc:0.86022
# [239]	validation_0-auc:0.91522	validation_1-auc:0.86024
# [240]	validation_0-auc:0.91527	validation_1-auc:0.86031
# [241]	validation_0-auc:0.91530	validation_1-auc:0.86028
# [242]	validation_0-auc:0.91533	validation_1-auc:0.86028
# [243]	validation_0-auc:0.91545	validation_1-auc:0.86012
# [244]	validation_0-auc:0.91549	validation_1-auc:0.86020
# [245]	validation_0-auc:0.91554	validation_1-auc:0.86020
# [246]	validation_0-auc:0.91580	validation_1-auc:0.86024
# [247]	validation_0-auc:0.91586	validation_1-auc:0.86020
# [248]	validation_0-auc:0.91591	validation_1-auc:0.86024
# [249]	validation_0-auc:0.91601	validation_1-auc:0.86023
# [250]	validation_0-auc:0.91609	validation_1-auc:0.86022
# [251]	validation_0-auc:0.91613	validation_1-auc:0.86017
# [252]	validation_0-auc:0.91616	validation_1-auc:0.86016
# [253]	validation_0-auc:0.91621	validation_1-auc:0.86015
# [254]	validation_0-auc:0.91622	validation_1-auc:0.86015
# [255]	validation_0-auc:0.91629	validation_1-auc:0.86022
# [256]	validation_0-auc:0.91634	validation_1-auc:0.86008
# [257]	validation_0-auc:0.91652	validation_1-auc:0.86020
# [258]	validation_0-auc:0.91655	validation_1-auc:0.86021
# [259]	validation_0-auc:0.91658	validation_1-auc:0.86024
# [260]	validation_0-auc:0.91664	validation_1-auc:0.86020
# [261]	validation_0-auc:0.91673	validation_1-auc:0.86021
# [262]	validation_0-auc:0.91678	validation_1-auc:0.86017
# [263]	validation_0-auc:0.91692	validation_1-auc:0.86023
# [264]	validation_0-auc:0.91707	validation_1-auc:0.86013
# [265]	validation_0-auc:0.91712	validation_1-auc:0.86009
# [266]	validation_0-auc:0.91714	validation_1-auc:0.86007
# [267]	validation_0-auc:0.91744	validation_1-auc:0.86015
# [268]	validation_0-auc:0.91752	validation_1-auc:0.86017
# [269]	validation_0-auc:0.91757	validation_1-auc:0.86023
# [270]	validation_0-auc:0.91760	validation_1-auc:0.86023
# [271]	validation_0-auc:0.91763	validation_1-auc:0.86020
# [272]	validation_0-auc:0.91777	validation_1-auc:0.86017
# [273]	validation_0-auc:0.91780	validation_1-auc:0.86015
# [274]	validation_0-auc:0.91800	validation_1-auc:0.86016
# [275]	validation_0-auc:0.91818	validation_1-auc:0.86021
# [276]	validation_0-auc:0.91821	validation_1-auc:0.86019
# [277]	validation_0-auc:0.91829	validation_1-auc:0.86022
# [278]	validation_0-auc:0.91835	validation_1-auc:0.86023
# [279]	validation_0-auc:0.91837	validation_1-auc:0.86018
# [280]	validation_0-auc:0.91841	validation_1-auc:0.86018
# [281]	validation_0-auc:0.91866	validation_1-auc:0.86025
# [282]	validation_0-auc:0.91871	validation_1-auc:0.86032
# [283]	validation_0-auc:0.91896	validation_1-auc:0.86026
# [284]	validation_0-auc:0.91904	validation_1-auc:0.86024
# [285]	validation_0-auc:0.91914	validation_1-auc:0.86030
# [286]	validation_0-auc:0.91922	validation_1-auc:0.86037
# [287]	validation_0-auc:0.91949	validation_1-auc:0.86033
# [288]	validation_0-auc:0.91956	validation_1-auc:0.86038
# [289]	validation_0-auc:0.91968	validation_1-auc:0.86038
# [290]	validation_0-auc:0.91977	validation_1-auc:0.86037
# [291]	validation_0-auc:0.91983	validation_1-auc:0.86038
# [292]	validation_0-auc:0.91987	validation_1-auc:0.86038
# [293]	validation_0-auc:0.92000	validation_1-auc:0.86030
# [294]	validation_0-auc:0.92007	validation_1-auc:0.86027
# [295]	validation_0-auc:0.92016	validation_1-auc:0.86024
# [296]	validation_0-auc:0.92029	validation_1-auc:0.86021
# [297]	validation_0-auc:0.92048	validation_1-auc:0.86021
# [298]	validation_0-auc:0.92051	validation_1-auc:0.86014
# [299]	validation_0-auc:0.92053	validation_1-auc:0.86015
#
# --------------------------------------
# ROC_AUC는 0.87070532592495 입니다
# recall_score는 0.8333333333333334 입니다
# precision_score는 0.038823272090988625 입니다
# accuracy_score는 0.7604369457062513 입니다
# --------------------------------------
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):

# %%
#모델2. LightGBMClassifier
from lightgbm import LGBMClassifier

lgbm_cf= LGBMClassifier(n_estimators=400, learning_rate=0.05)
#lightGBM도 XGBoost와 마찬가지로 조기 중단 수행이 가능하다
evals=[(X_tr,y_tr),(X_val,y_val)]
lgbm_cf.fit(X_tr,y_tr,early_stopping_rounds=50, eval_metric='logloss',eval_set=evals,verbose=True)
y_pred= lgbm_cf.predict(X_test)
pred_proba= lgbm_cf.predict_proba(X_test)[:,1]

#모델 평가
roc_val= roc_auc_score(y_test,y_pred)
recall_val= recall_score(y_test,y_pred)
accuracy_val= accuracy_score(y_test,y_pred)
precision_val= precision_score(y_test,y_pred)

print('\n--------------------------------------')
print(f'ROC_AUC는 {roc_val} 입니다')
print(f'recall_score는 {recall_val} 입니다')
print(f'precision_score는 {precision_val} 입니다')
print(f'accuracy_score는 {accuracy_val} 입니다')
print('--------------------------------------')
# Out:
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	training's binary_logloss: 0.059982	valid_1's binary_logloss: 0.0601226
# [2]	training's binary_logloss: 0.0585812	valid_1's binary_logloss: 0.0591987
# [3]	training's binary_logloss: 0.0575779	valid_1's binary_logloss: 0.0584372
# [4]	training's binary_logloss: 0.0567027	valid_1's binary_logloss: 0.05781
# [5]	training's binary_logloss: 0.0559288	valid_1's binary_logloss: 0.0572029
# [6]	training's binary_logloss: 0.0552388	valid_1's binary_logloss: 0.0566606
# [7]	training's binary_logloss: 0.0546377	valid_1's binary_logloss: 0.0561928
# [8]	training's binary_logloss: 0.0540953	valid_1's binary_logloss: 0.0557939
# [9]	training's binary_logloss: 0.0536138	valid_1's binary_logloss: 0.055399
# [10]	training's binary_logloss: 0.0531744	valid_1's binary_logloss: 0.0550575
# [11]	training's binary_logloss: 0.0527456	valid_1's binary_logloss: 0.0547414
# [12]	training's binary_logloss: 0.0523655	valid_1's binary_logloss: 0.0544492
# [13]	training's binary_logloss: 0.0520238	valid_1's binary_logloss: 0.0542084
# [14]	training's binary_logloss: 0.0517066	valid_1's binary_logloss: 0.0539893
# [15]	training's binary_logloss: 0.0514052	valid_1's binary_logloss: 0.0537657
# [16]	training's binary_logloss: 0.0511245	valid_1's binary_logloss: 0.0535859
# [17]	training's binary_logloss: 0.0508829	valid_1's binary_logloss: 0.0534055
# [18]	training's binary_logloss: 0.0506381	valid_1's binary_logloss: 0.0532639
# [19]	training's binary_logloss: 0.0504059	valid_1's binary_logloss: 0.0531015
# [20]	training's binary_logloss: 0.0501898	valid_1's binary_logloss: 0.0529846
# [21]	training's binary_logloss: 0.0499702	valid_1's binary_logloss: 0.0528595
# [22]	training's binary_logloss: 0.0497459	valid_1's binary_logloss: 0.0527417
# [23]	training's binary_logloss: 0.0495265	valid_1's binary_logloss: 0.0526023
# [24]	training's binary_logloss: 0.0493335	valid_1's binary_logloss: 0.0525042
# [25]	training's binary_logloss: 0.0491336	valid_1's binary_logloss: 0.0523954
# [26]	training's binary_logloss: 0.0489518	valid_1's binary_logloss: 0.0522858
# [27]	training's binary_logloss: 0.0487716	valid_1's binary_logloss: 0.0521737
# [28]	training's binary_logloss: 0.0486099	valid_1's binary_logloss: 0.0520823
# [29]	training's binary_logloss: 0.0484457	valid_1's binary_logloss: 0.0520087
# [30]	training's binary_logloss: 0.0482674	valid_1's binary_logloss: 0.0519484
# [31]	training's binary_logloss: 0.0481228	valid_1's binary_logloss: 0.0518387
# [32]	training's binary_logloss: 0.0479833	valid_1's binary_logloss: 0.0517799
# [33]	training's binary_logloss: 0.0478083	valid_1's binary_logloss: 0.0517121
# [34]	training's binary_logloss: 0.0476599	valid_1's binary_logloss: 0.0516497
# [35]	training's binary_logloss: 0.0475427	valid_1's binary_logloss: 0.0516103
# [36]	training's binary_logloss: 0.0474174	valid_1's binary_logloss: 0.0515366
# [37]	training's binary_logloss: 0.0472761	valid_1's binary_logloss: 0.0514889
# [38]	training's binary_logloss: 0.047157	valid_1's binary_logloss: 0.0514521
# [39]	training's binary_logloss: 0.047032	valid_1's binary_logloss: 0.0514142
# [40]	training's binary_logloss: 0.0469163	valid_1's binary_logloss: 0.0513575
# [41]	training's binary_logloss: 0.046788	valid_1's binary_logloss: 0.0513052
# [42]	training's binary_logloss: 0.0466575	valid_1's binary_logloss: 0.0512636
# [43]	training's binary_logloss: 0.0465529	valid_1's binary_logloss: 0.0512114
# [44]	training's binary_logloss: 0.0464542	valid_1's binary_logloss: 0.0511612
# [45]	training's binary_logloss: 0.0463388	valid_1's binary_logloss: 0.0511332
# [46]	training's binary_logloss: 0.0462187	valid_1's binary_logloss: 0.0511062
# [47]	training's binary_logloss: 0.0461141	valid_1's binary_logloss: 0.0510824
# [48]	training's binary_logloss: 0.0460141	valid_1's binary_logloss: 0.0510469
# [49]	training's binary_logloss: 0.0458863	valid_1's binary_logloss: 0.051026
# [50]	training's binary_logloss: 0.0457956	valid_1's binary_logloss: 0.0509887
# [51]	training's binary_logloss: 0.0457056	valid_1's binary_logloss: 0.0509615
# [52]	training's binary_logloss: 0.0456035	valid_1's binary_logloss: 0.0509305
# [53]	training's binary_logloss: 0.0455048	valid_1's binary_logloss: 0.0509095
# [54]	training's binary_logloss: 0.045421	valid_1's binary_logloss: 0.0508886
# [55]	training's binary_logloss: 0.0453005	valid_1's binary_logloss: 0.0508652
# [56]	training's binary_logloss: 0.0451868	valid_1's binary_logloss: 0.0508395
# [57]	training's binary_logloss: 0.0450942	valid_1's binary_logloss: 0.0508143
# [58]	training's binary_logloss: 0.0450075	valid_1's binary_logloss: 0.0508135
# [59]	training's binary_logloss: 0.0449151	valid_1's binary_logloss: 0.0508116
# [60]	training's binary_logloss: 0.0448363	valid_1's binary_logloss: 0.050789
# [61]	training's binary_logloss: 0.0447503	valid_1's binary_logloss: 0.0507726
# [62]	training's binary_logloss: 0.0446831	valid_1's binary_logloss: 0.050769
# [63]	training's binary_logloss: 0.0445624	valid_1's binary_logloss: 0.0507649
# [64]	training's binary_logloss: 0.0444752	valid_1's binary_logloss: 0.0507506
# [65]	training's binary_logloss: 0.0443838	valid_1's binary_logloss: 0.0507446
# [66]	training's binary_logloss: 0.0443015	valid_1's binary_logloss: 0.0507449
# [67]	training's binary_logloss: 0.0442166	valid_1's binary_logloss: 0.0507211
# [68]	training's binary_logloss: 0.044113	valid_1's binary_logloss: 0.0507035
# [69]	training's binary_logloss: 0.044041	valid_1's binary_logloss: 0.050691
# [70]	training's binary_logloss: 0.0439472	valid_1's binary_logloss: 0.0506754
# [71]	training's binary_logloss: 0.0438804	valid_1's binary_logloss: 0.0506726
# [72]	training's binary_logloss: 0.0438098	valid_1's binary_logloss: 0.0506682
# [73]	training's binary_logloss: 0.0437337	valid_1's binary_logloss: 0.0506659
# [74]	training's binary_logloss: 0.0436525	valid_1's binary_logloss: 0.0506665
# [75]	training's binary_logloss: 0.0435848	valid_1's binary_logloss: 0.0506636
# [76]	training's binary_logloss: 0.0435198	valid_1's binary_logloss: 0.0506654
# [77]	training's binary_logloss: 0.0434536	valid_1's binary_logloss: 0.0506723
# [78]	training's binary_logloss: 0.0433736	valid_1's binary_logloss: 0.0506748
# [79]	training's binary_logloss: 0.0433093	valid_1's binary_logloss: 0.05067
# [80]	training's binary_logloss: 0.0432094	valid_1's binary_logloss: 0.0506757
# [81]	training's binary_logloss: 0.0431428	valid_1's binary_logloss: 0.0506661
# [82]	training's binary_logloss: 0.0430658	valid_1's binary_logloss: 0.0506709
# [83]	training's binary_logloss: 0.0429771	valid_1's binary_logloss: 0.0506725
# [84]	training's binary_logloss: 0.0429012	valid_1's binary_logloss: 0.0506742
# [85]	training's binary_logloss: 0.04282	valid_1's binary_logloss: 0.0506741
# [86]	training's binary_logloss: 0.0427684	valid_1's binary_logloss: 0.0506708
# [87]	training's binary_logloss: 0.0427153	valid_1's binary_logloss: 0.0506788
# [88]	training's binary_logloss: 0.0426062	valid_1's binary_logloss: 0.0506829
# [89]	training's binary_logloss: 0.0425574	valid_1's binary_logloss: 0.0506845
# [90]	training's binary_logloss: 0.0425018	valid_1's binary_logloss: 0.0506793
# [91]	training's binary_logloss: 0.0424224	valid_1's binary_logloss: 0.0506831
# [92]	training's binary_logloss: 0.0423746	valid_1's binary_logloss: 0.0506757
# [93]	training's binary_logloss: 0.0423027	valid_1's binary_logloss: 0.050671
# [94]	training's binary_logloss: 0.0422474	valid_1's binary_logloss: 0.0506603
# [95]	training's binary_logloss: 0.0421935	valid_1's binary_logloss: 0.0506523
# [96]	training's binary_logloss: 0.0421035	valid_1's binary_logloss: 0.0506591
# [97]	training's binary_logloss: 0.0420353	valid_1's binary_logloss: 0.0506726
# [98]	training's binary_logloss: 0.0419808	valid_1's binary_logloss: 0.0506603
# [99]	training's binary_logloss: 0.0419079	valid_1's binary_logloss: 0.0506502
# [100]	training's binary_logloss: 0.0418613	valid_1's binary_logloss: 0.050642
# [101]	training's binary_logloss: 0.0418266	valid_1's binary_logloss: 0.0506459
# [102]	training's binary_logloss: 0.0417321	valid_1's binary_logloss: 0.050654
# [103]	training's binary_logloss: 0.0416874	valid_1's binary_logloss: 0.0506528
# [104]	training's binary_logloss: 0.0416435	valid_1's binary_logloss: 0.0506338
# [105]	training's binary_logloss: 0.0415768	valid_1's binary_logloss: 0.0506376
# [106]	training's binary_logloss: 0.0415189	valid_1's binary_logloss: 0.050627
# [107]	training's binary_logloss: 0.0414571	valid_1's binary_logloss: 0.0506286
# [108]	training's binary_logloss: 0.0414031	valid_1's binary_logloss: 0.050636
# [109]	training's binary_logloss: 0.0413652	valid_1's binary_logloss: 0.0506303
# [110]	training's binary_logloss: 0.0413094	valid_1's binary_logloss: 0.0506362
# [111]	training's binary_logloss: 0.0412672	valid_1's binary_logloss: 0.0506349
# [112]	training's binary_logloss: 0.0412251	valid_1's binary_logloss: 0.0506391
# [113]	training's binary_logloss: 0.0411561	valid_1's binary_logloss: 0.0506475
# [114]	training's binary_logloss: 0.0411189	valid_1's binary_logloss: 0.0506424
# [115]	training's binary_logloss: 0.0410584	valid_1's binary_logloss: 0.0506466
# [116]	training's binary_logloss: 0.0410009	valid_1's binary_logloss: 0.0506458
# [117]	training's binary_logloss: 0.0409492	valid_1's binary_logloss: 0.0506518
# [118]	training's binary_logloss: 0.0408897	valid_1's binary_logloss: 0.0506453
# [119]	training's binary_logloss: 0.0408319	valid_1's binary_logloss: 0.0506459
# [120]	training's binary_logloss: 0.0407871	valid_1's binary_logloss: 0.0506413
# [121]	training's binary_logloss: 0.0407403	valid_1's binary_logloss: 0.0506373
# [122]	training's binary_logloss: 0.0407003	valid_1's binary_logloss: 0.0506369
# [123]	training's binary_logloss: 0.0406496	valid_1's binary_logloss: 0.0506528
# [124]	training's binary_logloss: 0.0406074	valid_1's binary_logloss: 0.0506443
# [125]	training's binary_logloss: 0.040552	valid_1's binary_logloss: 0.0506488
# [126]	training's binary_logloss: 0.0404947	valid_1's binary_logloss: 0.0506543
# [127]	training's binary_logloss: 0.0404533	valid_1's binary_logloss: 0.0506514
# [128]	training's binary_logloss: 0.0404117	valid_1's binary_logloss: 0.0506508
# [129]	training's binary_logloss: 0.0403634	valid_1's binary_logloss: 0.0506495
# [130]	training's binary_logloss: 0.0403081	valid_1's binary_logloss: 0.0506591
# [131]	training's binary_logloss: 0.0402548	valid_1's binary_logloss: 0.0506615
# [132]	training's binary_logloss: 0.0402124	valid_1's binary_logloss: 0.0506707
# [133]	training's binary_logloss: 0.0401705	valid_1's binary_logloss: 0.0506708
# [134]	training's binary_logloss: 0.0401315	valid_1's binary_logloss: 0.0506746
# [135]	training's binary_logloss: 0.0400955	valid_1's binary_logloss: 0.0506807
# [136]	training's binary_logloss: 0.0400185	valid_1's binary_logloss: 0.0506854
# [137]	training's binary_logloss: 0.0399634	valid_1's binary_logloss: 0.0506857
# [138]	training's binary_logloss: 0.0399132	valid_1's binary_logloss: 0.050689
# [139]	training's binary_logloss: 0.0398744	valid_1's binary_logloss: 0.0506885
# [140]	training's binary_logloss: 0.0398228	valid_1's binary_logloss: 0.0506898
# [141]	training's binary_logloss: 0.0397862	valid_1's binary_logloss: 0.050691
# [142]	training's binary_logloss: 0.0397531	valid_1's binary_logloss: 0.0506962
# [143]	training's binary_logloss: 0.0397174	valid_1's binary_logloss: 0.050702
# [144]	training's binary_logloss: 0.039664	valid_1's binary_logloss: 0.0507077
# [145]	training's binary_logloss: 0.0396169	valid_1's binary_logloss: 0.0507091
# [146]	training's binary_logloss: 0.0395862	valid_1's binary_logloss: 0.0507109
# [147]	training's binary_logloss: 0.0395465	valid_1's binary_logloss: 0.0507228
# [148]	training's binary_logloss: 0.0394837	valid_1's binary_logloss: 0.0507378
# [149]	training's binary_logloss: 0.0394444	valid_1's binary_logloss: 0.0507339
# [150]	training's binary_logloss: 0.0394032	valid_1's binary_logloss: 0.0507325
# [151]	training's binary_logloss: 0.0393746	valid_1's binary_logloss: 0.0507333
# [152]	training's binary_logloss: 0.039338	valid_1's binary_logloss: 0.0507386
# [153]	training's binary_logloss: 0.0392951	valid_1's binary_logloss: 0.0507388
# [154]	training's binary_logloss: 0.0392589	valid_1's binary_logloss: 0.0507402
# [155]	training's binary_logloss: 0.0391911	valid_1's binary_logloss: 0.0507534
# [156]	training's binary_logloss: 0.0391468	valid_1's binary_logloss: 0.0507545
#
# --------------------------------------
# ROC_AUC는 0.5151351238895708 입니다
# recall_score는 0.03051643192488263 입니다
# precision_score는 0.5909090909090909 입니다
# accuracy_score는 0.9885896603936838 입니다
# --------------------------------------

# %%
#모델2-2. LightGBMClassifier - Binarizer 적용
from lightgbm import LGBMClassifier

lgbm_clf= LGBMClassifier(n_estimators=500, learning_rate=0.05)
#lightGBM도 XGBoost와 마찬가지로 조기 중단 수행이 가능하다
evals=[(X_tr,y_tr),(X_val,y_val)]
lgbm_clf.fit(X_tr,y_tr,early_stopping_rounds=100, eval_metric='logloss',eval_set=evals,verbose=True)
y_pred= lgbm_clf.predict(X_test)
pred_proba= lgbm_clf.predict_proba(X_test)[:,1]

#Binarizer 적용하기
custom_threshold= 0.01
y_pred_proba= lgbm_clf.predict_proba(X_test)[:,1].reshape(-1,1)
binarizer= Binarizer(threshold=custom_threshold).fit(pred_proba_1)
custom_predict= binarizer.transform(pred_proba_1)

#모델 평가
roc_val= roc_auc_score(y_test,y_pred_proba)
recall_val= recall_score(y_test,custom_predict)
accuracy_val= accuracy_score(y_test,custom_predict)
precision_val= precision_score(y_test,custom_predict)

print('\n--------------------------------------')
print(f'ROC_AUC는 {roc_val} 입니다')
print(f'recall_score는 {recall_val} 입니다')
print(f'precision_score는 {precision_val} 입니다')
print(f'accuracy_score는 {accuracy_val} 입니다')
print('--------------------------------------')
# Out:
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/lightgbm/sklearn.py:726: UserWarning: 'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. Pass 'early_stopping()' callback via 'callbacks' argument instead.
#   _log_warning("'early_stopping_rounds' argument is deprecated and will be removed in a future release of LightGBM. "
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/lightgbm/sklearn.py:736: UserWarning: 'verbose' argument is deprecated and will be removed in a future release of LightGBM. Pass 'log_evaluation()' callback via 'callbacks' argument instead.
#   _log_warning("'verbose' argument is deprecated and will be removed in a future release of LightGBM. "
# [1]	training's binary_logloss: 0.059982	valid_1's binary_logloss: 0.0601226
# [2]	training's binary_logloss: 0.0585812	valid_1's binary_logloss: 0.0591987
# [3]	training's binary_logloss: 0.0575779	valid_1's binary_logloss: 0.0584372
# [4]	training's binary_logloss: 0.0567027	valid_1's binary_logloss: 0.05781
# [5]	training's binary_logloss: 0.0559288	valid_1's binary_logloss: 0.0572029
# [6]	training's binary_logloss: 0.0552388	valid_1's binary_logloss: 0.0566606
# [7]	training's binary_logloss: 0.0546377	valid_1's binary_logloss: 0.0561928
# [8]	training's binary_logloss: 0.0540953	valid_1's binary_logloss: 0.0557939
# [9]	training's binary_logloss: 0.0536138	valid_1's binary_logloss: 0.055399
# [10]	training's binary_logloss: 0.0531744	valid_1's binary_logloss: 0.0550575
# [11]	training's binary_logloss: 0.0527456	valid_1's binary_logloss: 0.0547414
# [12]	training's binary_logloss: 0.0523655	valid_1's binary_logloss: 0.0544492
# [13]	training's binary_logloss: 0.0520238	valid_1's binary_logloss: 0.0542084
# [14]	training's binary_logloss: 0.0517066	valid_1's binary_logloss: 0.0539893
# [15]	training's binary_logloss: 0.0514052	valid_1's binary_logloss: 0.0537657
# [16]	training's binary_logloss: 0.0511245	valid_1's binary_logloss: 0.0535859
# [17]	training's binary_logloss: 0.0508829	valid_1's binary_logloss: 0.0534055
# [18]	training's binary_logloss: 0.0506381	valid_1's binary_logloss: 0.0532639
# [19]	training's binary_logloss: 0.0504059	valid_1's binary_logloss: 0.0531015
# [20]	training's binary_logloss: 0.0501898	valid_1's binary_logloss: 0.0529846
# [21]	training's binary_logloss: 0.0499702	valid_1's binary_logloss: 0.0528595
# [22]	training's binary_logloss: 0.0497459	valid_1's binary_logloss: 0.0527417
# [23]	training's binary_logloss: 0.0495265	valid_1's binary_logloss: 0.0526023
# [24]	training's binary_logloss: 0.0493335	valid_1's binary_logloss: 0.0525042
# [25]	training's binary_logloss: 0.0491336	valid_1's binary_logloss: 0.0523954
# [26]	training's binary_logloss: 0.0489518	valid_1's binary_logloss: 0.0522858
# [27]	training's binary_logloss: 0.0487716	valid_1's binary_logloss: 0.0521737
# [28]	training's binary_logloss: 0.0486099	valid_1's binary_logloss: 0.0520823
# [29]	training's binary_logloss: 0.0484457	valid_1's binary_logloss: 0.0520087
# [30]	training's binary_logloss: 0.0482674	valid_1's binary_logloss: 0.0519484
# [31]	training's binary_logloss: 0.0481228	valid_1's binary_logloss: 0.0518387
# [32]	training's binary_logloss: 0.0479833	valid_1's binary_logloss: 0.0517799
# [33]	training's binary_logloss: 0.0478083	valid_1's binary_logloss: 0.0517121
# [34]	training's binary_logloss: 0.0476599	valid_1's binary_logloss: 0.0516497
# [35]	training's binary_logloss: 0.0475427	valid_1's binary_logloss: 0.0516103
# [36]	training's binary_logloss: 0.0474174	valid_1's binary_logloss: 0.0515366
# [37]	training's binary_logloss: 0.0472761	valid_1's binary_logloss: 0.0514889
# [38]	training's binary_logloss: 0.047157	valid_1's binary_logloss: 0.0514521
# [39]	training's binary_logloss: 0.047032	valid_1's binary_logloss: 0.0514142
# [40]	training's binary_logloss: 0.0469163	valid_1's binary_logloss: 0.0513575
# [41]	training's binary_logloss: 0.046788	valid_1's binary_logloss: 0.0513052
# [42]	training's binary_logloss: 0.0466575	valid_1's binary_logloss: 0.0512636
# [43]	training's binary_logloss: 0.0465529	valid_1's binary_logloss: 0.0512114
# [44]	training's binary_logloss: 0.0464542	valid_1's binary_logloss: 0.0511612
# [45]	training's binary_logloss: 0.0463388	valid_1's binary_logloss: 0.0511332
# [46]	training's binary_logloss: 0.0462187	valid_1's binary_logloss: 0.0511062
# [47]	training's binary_logloss: 0.0461141	valid_1's binary_logloss: 0.0510824
# [48]	training's binary_logloss: 0.0460141	valid_1's binary_logloss: 0.0510469
# [49]	training's binary_logloss: 0.0458863	valid_1's binary_logloss: 0.051026
# [50]	training's binary_logloss: 0.0457956	valid_1's binary_logloss: 0.0509887
# [51]	training's binary_logloss: 0.0457056	valid_1's binary_logloss: 0.0509615
# [52]	training's binary_logloss: 0.0456035	valid_1's binary_logloss: 0.0509305
# [53]	training's binary_logloss: 0.0455048	valid_1's binary_logloss: 0.0509095
# [54]	training's binary_logloss: 0.045421	valid_1's binary_logloss: 0.0508886
# [55]	training's binary_logloss: 0.0453005	valid_1's binary_logloss: 0.0508652
# [56]	training's binary_logloss: 0.0451868	valid_1's binary_logloss: 0.0508395
# [57]	training's binary_logloss: 0.0450942	valid_1's binary_logloss: 0.0508143
# [58]	training's binary_logloss: 0.0450075	valid_1's binary_logloss: 0.0508135
# [59]	training's binary_logloss: 0.0449151	valid_1's binary_logloss: 0.0508116
# [60]	training's binary_logloss: 0.0448363	valid_1's binary_logloss: 0.050789
# [61]	training's binary_logloss: 0.0447503	valid_1's binary_logloss: 0.0507726
# [62]	training's binary_logloss: 0.0446831	valid_1's binary_logloss: 0.050769
# [63]	training's binary_logloss: 0.0445624	valid_1's binary_logloss: 0.0507649
# [64]	training's binary_logloss: 0.0444752	valid_1's binary_logloss: 0.0507506
# [65]	training's binary_logloss: 0.0443838	valid_1's binary_logloss: 0.0507446
# [66]	training's binary_logloss: 0.0443015	valid_1's binary_logloss: 0.0507449
# [67]	training's binary_logloss: 0.0442166	valid_1's binary_logloss: 0.0507211
# [68]	training's binary_logloss: 0.044113	valid_1's binary_logloss: 0.0507035
# [69]	training's binary_logloss: 0.044041	valid_1's binary_logloss: 0.050691
# [70]	training's binary_logloss: 0.0439472	valid_1's binary_logloss: 0.0506754
# [71]	training's binary_logloss: 0.0438804	valid_1's binary_logloss: 0.0506726
# [72]	training's binary_logloss: 0.0438098	valid_1's binary_logloss: 0.0506682
# [73]	training's binary_logloss: 0.0437337	valid_1's binary_logloss: 0.0506659
# [74]	training's binary_logloss: 0.0436525	valid_1's binary_logloss: 0.0506665
# [75]	training's binary_logloss: 0.0435848	valid_1's binary_logloss: 0.0506636
# [76]	training's binary_logloss: 0.0435198	valid_1's binary_logloss: 0.0506654
# [77]	training's binary_logloss: 0.0434536	valid_1's binary_logloss: 0.0506723
# [78]	training's binary_logloss: 0.0433736	valid_1's binary_logloss: 0.0506748
# [79]	training's binary_logloss: 0.0433093	valid_1's binary_logloss: 0.05067
# [80]	training's binary_logloss: 0.0432094	valid_1's binary_logloss: 0.0506757
# [81]	training's binary_logloss: 0.0431428	valid_1's binary_logloss: 0.0506661
# [82]	training's binary_logloss: 0.0430658	valid_1's binary_logloss: 0.0506709
# [83]	training's binary_logloss: 0.0429771	valid_1's binary_logloss: 0.0506725
# [84]	training's binary_logloss: 0.0429012	valid_1's binary_logloss: 0.0506742
# [85]	training's binary_logloss: 0.04282	valid_1's binary_logloss: 0.0506741
# [86]	training's binary_logloss: 0.0427684	valid_1's binary_logloss: 0.0506708
# [87]	training's binary_logloss: 0.0427153	valid_1's binary_logloss: 0.0506788
# [88]	training's binary_logloss: 0.0426062	valid_1's binary_logloss: 0.0506829
# [89]	training's binary_logloss: 0.0425574	valid_1's binary_logloss: 0.0506845
# [90]	training's binary_logloss: 0.0425018	valid_1's binary_logloss: 0.0506793
# [91]	training's binary_logloss: 0.0424224	valid_1's binary_logloss: 0.0506831
# [92]	training's binary_logloss: 0.0423746	valid_1's binary_logloss: 0.0506757
# [93]	training's binary_logloss: 0.0423027	valid_1's binary_logloss: 0.050671
# [94]	training's binary_logloss: 0.0422474	valid_1's binary_logloss: 0.0506603
# [95]	training's binary_logloss: 0.0421935	valid_1's binary_logloss: 0.0506523
# [96]	training's binary_logloss: 0.0421035	valid_1's binary_logloss: 0.0506591
# [97]	training's binary_logloss: 0.0420353	valid_1's binary_logloss: 0.0506726
# [98]	training's binary_logloss: 0.0419808	valid_1's binary_logloss: 0.0506603
# [99]	training's binary_logloss: 0.0419079	valid_1's binary_logloss: 0.0506502
# [100]	training's binary_logloss: 0.0418613	valid_1's binary_logloss: 0.050642
# [101]	training's binary_logloss: 0.0418266	valid_1's binary_logloss: 0.0506459
# [102]	training's binary_logloss: 0.0417321	valid_1's binary_logloss: 0.050654
# [103]	training's binary_logloss: 0.0416874	valid_1's binary_logloss: 0.0506528
# [104]	training's binary_logloss: 0.0416435	valid_1's binary_logloss: 0.0506338
# [105]	training's binary_logloss: 0.0415768	valid_1's binary_logloss: 0.0506376
# [106]	training's binary_logloss: 0.0415189	valid_1's binary_logloss: 0.050627
# [107]	training's binary_logloss: 0.0414571	valid_1's binary_logloss: 0.0506286
# [108]	training's binary_logloss: 0.0414031	valid_1's binary_logloss: 0.050636
# [109]	training's binary_logloss: 0.0413652	valid_1's binary_logloss: 0.0506303
# [110]	training's binary_logloss: 0.0413094	valid_1's binary_logloss: 0.0506362
# [111]	training's binary_logloss: 0.0412672	valid_1's binary_logloss: 0.0506349
# [112]	training's binary_logloss: 0.0412251	valid_1's binary_logloss: 0.0506391
# [113]	training's binary_logloss: 0.0411561	valid_1's binary_logloss: 0.0506475
# [114]	training's binary_logloss: 0.0411189	valid_1's binary_logloss: 0.0506424
# [115]	training's binary_logloss: 0.0410584	valid_1's binary_logloss: 0.0506466
# [116]	training's binary_logloss: 0.0410009	valid_1's binary_logloss: 0.0506458
# [117]	training's binary_logloss: 0.0409492	valid_1's binary_logloss: 0.0506518
# [118]	training's binary_logloss: 0.0408897	valid_1's binary_logloss: 0.0506453
# [119]	training's binary_logloss: 0.0408319	valid_1's binary_logloss: 0.0506459
# [120]	training's binary_logloss: 0.0407871	valid_1's binary_logloss: 0.0506413
# [121]	training's binary_logloss: 0.0407403	valid_1's binary_logloss: 0.0506373
# [122]	training's binary_logloss: 0.0407003	valid_1's binary_logloss: 0.0506369
# [123]	training's binary_logloss: 0.0406496	valid_1's binary_logloss: 0.0506528
# [124]	training's binary_logloss: 0.0406074	valid_1's binary_logloss: 0.0506443
# [125]	training's binary_logloss: 0.040552	valid_1's binary_logloss: 0.0506488
# [126]	training's binary_logloss: 0.0404947	valid_1's binary_logloss: 0.0506543
# [127]	training's binary_logloss: 0.0404533	valid_1's binary_logloss: 0.0506514
# [128]	training's binary_logloss: 0.0404117	valid_1's binary_logloss: 0.0506508
# [129]	training's binary_logloss: 0.0403634	valid_1's binary_logloss: 0.0506495
# [130]	training's binary_logloss: 0.0403081	valid_1's binary_logloss: 0.0506591
# [131]	training's binary_logloss: 0.0402548	valid_1's binary_logloss: 0.0506615
# [132]	training's binary_logloss: 0.0402124	valid_1's binary_logloss: 0.0506707
# [133]	training's binary_logloss: 0.0401705	valid_1's binary_logloss: 0.0506708
# [134]	training's binary_logloss: 0.0401315	valid_1's binary_logloss: 0.0506746
# [135]	training's binary_logloss: 0.0400955	valid_1's binary_logloss: 0.0506807
# [136]	training's binary_logloss: 0.0400185	valid_1's binary_logloss: 0.0506854
# [137]	training's binary_logloss: 0.0399634	valid_1's binary_logloss: 0.0506857
# [138]	training's binary_logloss: 0.0399132	valid_1's binary_logloss: 0.050689
# [139]	training's binary_logloss: 0.0398744	valid_1's binary_logloss: 0.0506885
# [140]	training's binary_logloss: 0.0398228	valid_1's binary_logloss: 0.0506898
# [141]	training's binary_logloss: 0.0397862	valid_1's binary_logloss: 0.050691
# [142]	training's binary_logloss: 0.0397531	valid_1's binary_logloss: 0.0506962
# [143]	training's binary_logloss: 0.0397174	valid_1's binary_logloss: 0.050702
# [144]	training's binary_logloss: 0.039664	valid_1's binary_logloss: 0.0507077
# [145]	training's binary_logloss: 0.0396169	valid_1's binary_logloss: 0.0507091
# [146]	training's binary_logloss: 0.0395862	valid_1's binary_logloss: 0.0507109
# [147]	training's binary_logloss: 0.0395465	valid_1's binary_logloss: 0.0507228
# [148]	training's binary_logloss: 0.0394837	valid_1's binary_logloss: 0.0507378
# [149]	training's binary_logloss: 0.0394444	valid_1's binary_logloss: 0.0507339
# [150]	training's binary_logloss: 0.0394032	valid_1's binary_logloss: 0.0507325
# [151]	training's binary_logloss: 0.0393746	valid_1's binary_logloss: 0.0507333
# [152]	training's binary_logloss: 0.039338	valid_1's binary_logloss: 0.0507386
# [153]	training's binary_logloss: 0.0392951	valid_1's binary_logloss: 0.0507388
# [154]	training's binary_logloss: 0.0392589	valid_1's binary_logloss: 0.0507402
# [155]	training's binary_logloss: 0.0391911	valid_1's binary_logloss: 0.0507534
# [156]	training's binary_logloss: 0.0391468	valid_1's binary_logloss: 0.0507545
# [157]	training's binary_logloss: 0.039096	valid_1's binary_logloss: 0.0507562
# [158]	training's binary_logloss: 0.039033	valid_1's binary_logloss: 0.0507492
# [159]	training's binary_logloss: 0.0389976	valid_1's binary_logloss: 0.0507462
# [160]	training's binary_logloss: 0.0389602	valid_1's binary_logloss: 0.0507535
# [161]	training's binary_logloss: 0.0389294	valid_1's binary_logloss: 0.0507552
# [162]	training's binary_logloss: 0.0388912	valid_1's binary_logloss: 0.050748
# [163]	training's binary_logloss: 0.0388529	valid_1's binary_logloss: 0.0507418
# [164]	training's binary_logloss: 0.0388166	valid_1's binary_logloss: 0.0507458
# [165]	training's binary_logloss: 0.038757	valid_1's binary_logloss: 0.0507486
# [166]	training's binary_logloss: 0.0387221	valid_1's binary_logloss: 0.0507492
# [167]	training's binary_logloss: 0.038695	valid_1's binary_logloss: 0.0507534
# [168]	training's binary_logloss: 0.0386366	valid_1's binary_logloss: 0.0507547
# [169]	training's binary_logloss: 0.0385732	valid_1's binary_logloss: 0.0507523
# [170]	training's binary_logloss: 0.0385413	valid_1's binary_logloss: 0.050747
# [171]	training's binary_logloss: 0.0384721	valid_1's binary_logloss: 0.0507568
# [172]	training's binary_logloss: 0.0384313	valid_1's binary_logloss: 0.0507659
# [173]	training's binary_logloss: 0.0383974	valid_1's binary_logloss: 0.0507631
# [174]	training's binary_logloss: 0.0383706	valid_1's binary_logloss: 0.0507725
# [175]	training's binary_logloss: 0.0383228	valid_1's binary_logloss: 0.050778
# [176]	training's binary_logloss: 0.0382964	valid_1's binary_logloss: 0.0507759
# [177]	training's binary_logloss: 0.0382688	valid_1's binary_logloss: 0.0507753
# [178]	training's binary_logloss: 0.038218	valid_1's binary_logloss: 0.0507816
# [179]	training's binary_logloss: 0.038178	valid_1's binary_logloss: 0.0507932
# [180]	training's binary_logloss: 0.0381586	valid_1's binary_logloss: 0.0507915
# [181]	training's binary_logloss: 0.0381155	valid_1's binary_logloss: 0.0507945
# [182]	training's binary_logloss: 0.0380725	valid_1's binary_logloss: 0.0508025
# [183]	training's binary_logloss: 0.0380263	valid_1's binary_logloss: 0.0508116
# [184]	training's binary_logloss: 0.0379896	valid_1's binary_logloss: 0.0508259
# [185]	training's binary_logloss: 0.0379565	valid_1's binary_logloss: 0.0508257
# [186]	training's binary_logloss: 0.037932	valid_1's binary_logloss: 0.0508236
# [187]	training's binary_logloss: 0.0379097	valid_1's binary_logloss: 0.0508261
# [188]	training's binary_logloss: 0.0378832	valid_1's binary_logloss: 0.0508298
# [189]	training's binary_logloss: 0.0378526	valid_1's binary_logloss: 0.0508403
# [190]	training's binary_logloss: 0.0378126	valid_1's binary_logloss: 0.0508488
# [191]	training's binary_logloss: 0.0377731	valid_1's binary_logloss: 0.0508616
# [192]	training's binary_logloss: 0.0377233	valid_1's binary_logloss: 0.0508689
# [193]	training's binary_logloss: 0.0376747	valid_1's binary_logloss: 0.0508797
# [194]	training's binary_logloss: 0.0376152	valid_1's binary_logloss: 0.050875
# [195]	training's binary_logloss: 0.0375856	valid_1's binary_logloss: 0.0508798
# [196]	training's binary_logloss: 0.0375594	valid_1's binary_logloss: 0.0508808
# [197]	training's binary_logloss: 0.0375376	valid_1's binary_logloss: 0.0508814
# [198]	training's binary_logloss: 0.0375105	valid_1's binary_logloss: 0.0508808
# [199]	training's binary_logloss: 0.0374617	valid_1's binary_logloss: 0.0508719
# [200]	training's binary_logloss: 0.0374252	valid_1's binary_logloss: 0.0508807
# [201]	training's binary_logloss: 0.0373751	valid_1's binary_logloss: 0.0508843
# [202]	training's binary_logloss: 0.0373334	valid_1's binary_logloss: 0.0508853
# [203]	training's binary_logloss: 0.0373009	valid_1's binary_logloss: 0.0508853
# [204]	training's binary_logloss: 0.0372773	valid_1's binary_logloss: 0.0508881
# [205]	training's binary_logloss: 0.0372216	valid_1's binary_logloss: 0.0508922
# [206]	training's binary_logloss: 0.0371873	valid_1's binary_logloss: 0.0509014
#
# --------------------------------------
# ROC_AUC는 0.8691567865533372 입니다
# recall_score는 0.823943661971831 입니다
# precision_score는 0.03934977578475336 입니다
# accuracy_score는 0.7662773091066407 입니다
# --------------------------------------

# %%
#모델3. 로지스틱 회귀

from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV

lr_clf= LogisticRegression(max_iter=1000)
lr_clf.fit(X_train,y_train)
y_pred= lr_clf.predict(X_test)
y_pred_proba= lr_clf.predict_proba(X_test)[:,1]

#모델 평가
roc_val= roc_auc_score(y_test,y_pred_proba)
recall_val= recall_score(y_test,y_pred)
accuracy_val= accuracy_score(y_test,y_pred)
precision_val= precision_score(y_test,y_pred)

print('\n--------------------------------------')
print(f'ROC_AUC는 {roc_val} 입니다')
print(f'recall_score는 {recall_val} 입니다')
print(f'precision_score는 {precision_val} 입니다')
print(f'accuracy_score는 {accuracy_val} 입니다')
print('--------------------------------------')
# Out:
# --------------------------------------
# ROC_AUC는 0.8527019384208308 입니다
# recall_score는 0.014084507042253521 입니다
# precision_score는 0.4 입니다
# accuracy_score는 0.98840038935756 입니다
# --------------------------------------
# /Users/wooseongkyun/miniforge3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
#모델4. 랜덤 포레스트
from sklearn.ensemble import RandomForestClassifier

rf_clf= RandomForestClassifier(random_state=0,max_depth=8)
rf_clf.fit(X_train,y_train)
y_pred= rf_clf.predict(X_test)
y_pred_proba= rf_clf.predict_proba(X_test)[:,1]

#모델 평가
xgb_roc_val= roc_auc_score(y_test,y_pred_proba)
recall_val= recall_score(y_test,y_pred)
accuracy_val= accuracy_score(y_test,y_pred)
precision_val= precision_score(y_test,y_pred)
print('\n--------------------------------------')
#print(f'ROC_AUC는 {xgb_roc_score} 입니다')
#print(f'precision_score는 {precision_score} 입니다')
print('\n--------------------------------------')
print(f'ROC_AUC는 {xgb_roc_val} 입니다')
print(f'precision_score는 {precision_val} 입니다')
print(f'recall_score는 {recall_val} 입니다')
print(f'accuracy_score는 {accuracy_val} 입니다')
print('--------------------------------------')

# %%
# #모델 평가
# xgb_roc_score= roc_auc_score(y_test,y_pred_proba)
# recall_score= recall_score(y_test,y_pred)
# accuracy_score= accuracy_score(y_test,y_pred)
# precision_score= precision_score(y_test,y_pred)
# print('\n--------------------------------------')
# print(f'ROC_AUC는 {xgb_roc_score} 입니다')
# print(f'precision_score는 {precision_score} 입니다')
# print(f'recall_score는 {recall_score} 입니다')
# print(f'accuracy_score는 {accuracy_score} 입니다')
# print('--------------------------------------')
# #recall_score가 0.036231884057971016: 대부분을 사망안함 0으로 예측안함으로 다른 지표값들을 높여서 이런 현상이 발생했을 가능성이 높음
